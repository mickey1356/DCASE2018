# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %matplotlib inline

seed = 1356

raw_data = pd.read_pickle("domestic_audio_features.pkl")

# %%
afs, labels, _ = zip(*[line.rstrip('\n').split('\t') for line in open('DCASE2018-task5-dev.meta/DCASE2018-task5-dev/meta.txt').readlines()])

# %%
sces = set(labels)
sce_int_map = {sce:i+1 for i,sce in enumerate(list(sces))}
int_sce_map = {sce_int_map[i]:i for i in sce_int_map.keys()}

# %%
raw_data.head()
# Out:
#    label  mfcc_01_mean  mfcc_01_std  mfcc_02_mean  mfcc_02_std  mfcc_03_mean  \
# 0      9   -336.051919    72.676704     52.751568    50.311581     20.932058
# 1      9   -336.854385    77.127879     25.032802    31.575797     11.374043
# 2      9   -357.847449    64.125447     30.350622    20.617674     12.364442
# 3      9   -314.862922    66.357897      8.575267    25.946491     10.373437
# 4      9   -335.962007    70.711474     54.434298    38.431890     15.171099
#
#    mfcc_03_std  mfcc_04_mean  mfcc_04_std  mfcc_05_mean    ...     rmse_mean  \
# 0    15.137371     22.713074    10.642034     13.676562    ...      0.051768
# 1    16.556974     13.848688     8.344629     11.240080    ...      0.046316
# 2     8.837606     12.060213    11.345274      9.299338    ...      0.043852
# 3    10.781843     13.793221     7.895745      9.271161    ...      0.044296
# 4    13.887398     14.233967    11.697274     10.299907    ...      0.047941
#
#    rmse_std  rolloff_mean  rolloff_std  spec_centoid_mean  spec_centoid_std  \
# 0  0.039705   3600.289537  1720.669191        1469.152555        883.046342
# 1  0.015529   4702.051717  1401.513136        1892.227442        923.234354
# 2  0.000479   4420.377396  1346.985001        1676.309097        773.329444
# 3  0.001244   5490.415335  1152.930682        2336.224332        858.833091
# 4  0.016913   3716.328874  1350.669698        1438.245156        664.098987
#
#    spec_flux_mean  spec_flux_std  zcr_mean   zcr_std
# 0        1.055207       1.524605  0.006329  0.020022
# 1        1.027018       1.234435  0.005552  0.025613
# 2        0.879802       0.785668  0.000212  0.001167
# 3        1.201696       1.554686  0.002870  0.010235
# 4        1.072010       1.322863  0.004752  0.012924
#
# [5 rows x 51 columns]

# %%
# split the data such that each label is equally represented
balanced_data = raw_data.groupby('label')
balanced_data = balanced_data.apply(lambda x: x.sample(balanced_data.size().min(), random_state=seed).reset_index(drop=True))
y = balanced_data['label']
X = balanced_data.drop('label', axis=1)

# %%
y_unbal = raw_data['label']
X_unbal = raw_data.drop('label', axis=1)

# %%
# split data into stratified folds for cross validation
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=4, random_state=seed)

# %%
# create helper function for classifier
from sklearn import preprocessing
from sklearn.metrics import f1_score

# for each fold,
# preprocess data into std, minmax and raw
# train clf for each preprocessing method
# get the score for each preprocessing method
# display avg f-score for each preprocessing method

def cross_val(X, y, clf, skf):
    nppac = stdac = mmac = 0
    for i, (train, test) in enumerate(skf.split(X, y)):
        X_train, X_test = X.values[train], X.values[test]
        y_train, y_test = y.values[train], y.values[test]
        
        # standard
        std_scaler = preprocessing.StandardScaler().fit(X_train)
        X_train_std = std_scaler.transform(X_train)
        X_test_std = std_scaler.transform(X_test)

        # min max scaling
        minmax_scaler = preprocessing.MinMaxScaler().fit(X_train)
        X_train_minmax = minmax_scaler.transform(X_train)
        X_test_minmax = minmax_scaler.transform(X_test)
        
        # no preprocessing
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        score = f1_score(y_test, y_pred, average='macro')
        print("No pre-processing, fold {0}: {1:.5f}".format(i+1, score))
        nppac += score
        
        # std
        clf.fit(X_train_std, y_train)
        y_pred = clf.predict(X_test_std)
        score = f1_score(y_test, y_pred, average='macro')
        print("Standard pre-processing, fold {0}: {1:.5f}".format(i+1, score))
        stdac += score
        
        # minmax
        clf.fit(X_train_minmax, y_train)
        y_pred = clf.predict(X_test_minmax)
        score = f1_score(y_test, y_pred, average='macro')
        print("Min-max pre-processing, fold {0}: {1:.5f}".format(i+1, score))
        mmac += score
        print()
    print("======================================================")
    print("No pre-processing average: {:.5f}".format(nppac / 4))
    print("Standard pre-processing average: {:.5f}".format(stdac / 4))
    print("Min-max pre-processing average: {:.5f}".format(mmac / 4))
    print("======================================================")

# %%
# knn
from sklearn.neighbors import KNeighborsClassifier
neigh=KNeighborsClassifier(n_neighbors = 1)
cross_val(X, y, neigh, skf)
# Out:
# No pre-processing, fold 1: 0.58228
# Standard pre-processing, fold 1: 0.84789
# Min-max pre-processing, fold 1: 0.84655
#
# No pre-processing, fold 2: 0.60467
# Standard pre-processing, fold 2: 0.85608
# Min-max pre-processing, fold 2: 0.86045
#
# No pre-processing, fold 3: 0.57359
# Standard pre-processing, fold 3: 0.84712
# Min-max pre-processing, fold 3: 0.84899
#
# No pre-processing, fold 4: 0.60140
# Standard pre-processing, fold 4: 0.84501
# Min-max pre-processing, fold 4: 0.84664
#
# ======================================================
# No pre-processing average: 0.59049
# Standard pre-processing average: 0.84902
# Min-max pre-processing average: 0.85066
# ======================================================

# %%
# knn
from sklearn.neighbors import KNeighborsClassifier
neigh=KNeighborsClassifier(n_neighbors = 3)
cross_val(X, y, neigh, skf)
# Out:
# No pre-processing, fold 1: 0.58448
# Standard pre-processing, fold 1: 0.84705
# Min-max pre-processing, fold 1: 0.84371
#
# No pre-processing, fold 2: 0.61776
# Standard pre-processing, fold 2: 0.86150
# Min-max pre-processing, fold 2: 0.86267
#
# No pre-processing, fold 3: 0.59800
# Standard pre-processing, fold 3: 0.84717
# Min-max pre-processing, fold 3: 0.84363
#
# No pre-processing, fold 4: 0.59995
# Standard pre-processing, fold 4: 0.84813
# Min-max pre-processing, fold 4: 0.84842
#
# ======================================================
# No pre-processing average: 0.60005
# Standard pre-processing average: 0.85096
# Min-max pre-processing average: 0.84961
# ======================================================

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
C_values = [0.001, 0.01, 0.1, 1, 10, 100] # small C means underfitting
for c in C_values:
    logre=LogisticRegression(C=c, random_state=seed, solver='sag', max_iter=500)
    print("C value: {}".format(c))
    cross_val(X, y, logre, skf)
    print()
# Out:
# C value: 0.001
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# No pre-processing, fold 1: 0.71411
# Standard pre-processing, fold 1: 0.71451
# Min-max pre-processing, fold 1: 0.49160
#
# No pre-processing, fold 2: 0.72903
# Standard pre-processing, fold 2: 0.74080
# Min-max pre-processing, fold 2: 0.50266
#
# No pre-processing, fold 3: 0.72104
# Standard pre-processing, fold 3: 0.71539
# Min-max pre-processing, fold 3: 0.50325
#
# No pre-processing, fold 4: 0.72924
# Standard pre-processing, fold 4: 0.72286
# Min-max pre-processing, fold 4: 0.49356
#
# ======================================================
# No pre-processing average: 0.72336
# Standard pre-processing average: 0.72339
# Min-max pre-processing average: 0.49777
# ======================================================
#
# C value: 0.01
# No pre-processing, fold 1: 0.71516
# Standard pre-processing, fold 1: 0.78030
# Min-max pre-processing, fold 1: 0.64950
#
# No pre-processing, fold 2: 0.73073
# Standard pre-processing, fold 2: 0.80138
# Min-max pre-processing, fold 2: 0.69101
#
# No pre-processing, fold 3: 0.72274
# Standard pre-processing, fold 3: 0.78774
# Min-max pre-processing, fold 3: 0.66102
#
# No pre-processing, fold 4: 0.72878
# Standard pre-processing, fold 4: 0.79046
# Min-max pre-processing, fold 4: 0.66482
#
# ======================================================
# No pre-processing average: 0.72435
# Standard pre-processing average: 0.78997
# Min-max pre-processing average: 0.66659
# ======================================================
#
# C value: 0.1
# No pre-processing, fold 1: 0.71568
# Standard pre-processing, fold 1: 0.82147
# Min-max pre-processing, fold 1: 0.73749
#
# No pre-processing, fold 2: 0.73074
# Standard pre-processing, fold 2: 0.83335
# Min-max pre-processing, fold 2: 0.76023
#
# No pre-processing, fold 3: 0.72274
# Standard pre-processing, fold 3: 0.82381
# Min-max pre-processing, fold 3: 0.74586
#
# No pre-processing, fold 4: 0.72878
# Standard pre-processing, fold 4: 0.83071
# Min-max pre-processing, fold 4: 0.74645
#
# ======================================================
# No pre-processing average: 0.72449
# Standard pre-processing average: 0.82734
# Min-max pre-processing average: 0.74751
# ======================================================
#
# C value: 1
# No pre-processing, fold 1: 0.71568
# Standard pre-processing, fold 1: 0.82553
# Min-max pre-processing, fold 1: 0.79855
#
# No pre-processing, fold 2: 0.73074
# Standard pre-processing, fold 2: 0.84406
# Min-max pre-processing, fold 2: 0.81555
#
# No pre-processing, fold 3: 0.72274
# Standard pre-processing, fold 3: 0.83862
# Min-max pre-processing, fold 3: 0.79867
#
# No pre-processing, fold 4: 0.72878
# Standard pre-processing, fold 4: 0.83697
# Min-max pre-processing, fold 4: 0.80794
#
# ======================================================
# No pre-processing average: 0.72449
# Standard pre-processing average: 0.83629
# Min-max pre-processing average: 0.80518
# ======================================================
#
# C value: 10
# No pre-processing, fold 1: 0.71568
# Standard pre-processing, fold 1: 0.82999
# Min-max pre-processing, fold 1: 0.82613
#
# No pre-processing, fold 2: 0.73074
# Standard pre-processing, fold 2: 0.84217
# Min-max pre-processing, fold 2: 0.84128
#
# No pre-processing, fold 3: 0.72274
# Standard pre-processing, fold 3: 0.84308
# Min-max pre-processing, fold 3: 0.82998
#
# No pre-processing, fold 4: 0.72878
# Standard pre-processing, fold 4: 0.83445
# Min-max pre-processing, fold 4: 0.83376
#
# ======================================================
# No pre-processing average: 0.72449
# Standard pre-processing average: 0.83742
# Min-max pre-processing average: 0.83279
# ======================================================
#
# C value: 100
# No pre-processing, fold 1: 0.71568
# Standard pre-processing, fold 1: 0.83078
# Min-max pre-processing, fold 1: 0.82900
#
# No pre-processing, fold 2: 0.73074
# Standard pre-processing, fold 2: 0.84131
# Min-max pre-processing, fold 2: 0.84317
#
# No pre-processing, fold 3: 0.72274
# Standard pre-processing, fold 3: 0.84366
# Min-max pre-processing, fold 3: 0.84046
#
# No pre-processing, fold 4: 0.72878
# Standard pre-processing, fold 4: 0.83404
# Min-max pre-processing, fold 4: 0.83530
#
# ======================================================
# No pre-processing average: 0.72449
# Standard pre-processing average: 0.83745
# Min-max pre-processing average: 0.83698
# ======================================================

# %%
# svm kernel: rbf
from sklearn.svm import SVC

poly_deg = [1, 2, 3, 4]
gamma_val = [0.001, 0.01, 0.1, 1, 10, 100]
C_values = [0.001, 0.01, 0.1, 1, 10, 100]
kernels = ['rbf']

for kernel in kernels:
    print("Kernel: {}".format(kernel))
    if kernel == 'linear':
        for c in C_values:
            svm=SVC(kernel=kernel, C=c, random_state=seed, max_iter=500)
            print("C value: {}".format(c))
            cross_val(X, y, svm, skf)
            print()
    if kernel == 'poly':
        for c in C_values:
            for deg in poly_deg:
                for gamma in gamma_val:
                    svm=SVC(kernel=kernel, C=c, degree=degree, gamma=gamma, random_state=seed, max_iter=500)
                    print("C: {0}, Degrees: {1}, Gamma: {2}".format(c, degree, gamma))
                    cross_val(X, y, svm, skf)
                    print()
    if kernel == 'rbf':
        for c in C_values:
            for gamma in gamma_val:
                svm=SVC(kernel=kernel, C=c, gamma=gamma, random_state=seed, max_iter=500)
                print("C: {0}, Gamma: {1}".format(c, gamma))
                cross_val(X, y, svm, skf)
                print()
# Out:
# Kernel: rbf
# C: 0.001, Gamma: 0.001
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\base.py:218: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# No pre-processing, fold 1: 0.48975
# Standard pre-processing, fold 1: 0.48491
# Min-max pre-processing, fold 1: 0.52561
#
# No pre-processing, fold 2: 0.50226
# Standard pre-processing, fold 2: 0.43799
# Min-max pre-processing, fold 2: 0.55838
#
# No pre-processing, fold 3: 0.46852
# Standard pre-processing, fold 3: 0.49048
# Min-max pre-processing, fold 3: 0.52680
#
# No pre-processing, fold 4: 0.49224
# Standard pre-processing, fold 4: 0.50504
# Min-max pre-processing, fold 4: 0.52948
#
# ======================================================
# No pre-processing average: 0.48819
# Standard pre-processing average: 0.47961
# Min-max pre-processing average: 0.53507
# ======================================================
#
# C: 0.001, Gamma: 0.01
# No pre-processing, fold 1: 0.54721
# Standard pre-processing, fold 1: 0.61288
# Min-max pre-processing, fold 1: 0.52561
#
# No pre-processing, fold 2: 0.56737
# Standard pre-processing, fold 2: 0.62726
# Min-max pre-processing, fold 2: 0.56479
#
# No pre-processing, fold 3: 0.54373
# Standard pre-processing, fold 3: 0.60596
# Min-max pre-processing, fold 3: 0.51045
#
# No pre-processing, fold 4: 0.56218
# Standard pre-processing, fold 4: 0.66665
# Min-max pre-processing, fold 4: 0.53844
#
# ======================================================
# No pre-processing average: 0.55512
# Standard pre-processing average: 0.62819
# Min-max pre-processing average: 0.53482
# ======================================================
#
# C: 0.001, Gamma: 0.1
# No pre-processing, fold 1: 0.41114
# Standard pre-processing, fold 1: 0.71020
# Min-max pre-processing, fold 1: 0.58936
#
# No pre-processing, fold 2: 0.43168
# Standard pre-processing, fold 2: 0.74379
# Min-max pre-processing, fold 2: 0.59537
#
# No pre-processing, fold 3: 0.41026
# Standard pre-processing, fold 3: 0.73148
# Min-max pre-processing, fold 3: 0.57890
#
# No pre-processing, fold 4: 0.41001
# Standard pre-processing, fold 4: 0.73601
# Min-max pre-processing, fold 4: 0.56570
#
# ======================================================
# No pre-processing average: 0.41577
# Standard pre-processing average: 0.73037
# Min-max pre-processing average: 0.58233
# ======================================================
#
# C: 0.001, Gamma: 1
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# No pre-processing, fold 1: 0.12335
# Standard pre-processing, fold 1: 0.58021
# Min-max pre-processing, fold 1: 0.69750
#
# No pre-processing, fold 2: 0.12174
# Standard pre-processing, fold 2: 0.60846
# Min-max pre-processing, fold 2: 0.73652
#
# No pre-processing, fold 3: 0.12403
# Standard pre-processing, fold 3: 0.59768
# Min-max pre-processing, fold 3: 0.71001
#
# No pre-processing, fold 4: 0.12072
# Standard pre-processing, fold 4: 0.58125
# Min-max pre-processing, fold 4: 0.71921
#
# ======================================================
# No pre-processing average: 0.12246
# Standard pre-processing average: 0.59190
# Min-max pre-processing average: 0.71581
# ======================================================
#
# C: 0.001, Gamma: 10
# No pre-processing, fold 1: 0.02763
# Standard pre-processing, fold 1: 0.72425
# Min-max pre-processing, fold 1: 0.68270
#
# No pre-processing, fold 2: 0.02935
# Standard pre-processing, fold 2: 0.76817
# Min-max pre-processing, fold 2: 0.71348
#
# No pre-processing, fold 3: 0.02939
# Standard pre-processing, fold 3: 0.72503
# Min-max pre-processing, fold 3: 0.70021
#
# No pre-processing, fold 4: 0.02942
# Standard pre-processing, fold 4: 0.77450
# Min-max pre-processing, fold 4: 0.69398
#
# ======================================================
# No pre-processing average: 0.02895
# Standard pre-processing average: 0.74799
# Min-max pre-processing average: 0.69759
# ======================================================
#
# C: 0.001, Gamma: 100
# No pre-processing, fold 1: 0.02222
# Standard pre-processing, fold 1: 0.56240
# Min-max pre-processing, fold 1: 0.54728
#
# No pre-processing, fold 2: 0.02214
# Standard pre-processing, fold 2: 0.58835
# Min-max pre-processing, fold 2: 0.55778
#
# No pre-processing, fold 3: 0.02222
# Standard pre-processing, fold 3: 0.58241
# Min-max pre-processing, fold 3: 0.55387
#
# No pre-processing, fold 4: 0.02222
# Standard pre-processing, fold 4: 0.57838
# Min-max pre-processing, fold 4: 0.54822
#
# ======================================================
# No pre-processing average: 0.02220
# Standard pre-processing average: 0.57789
# Min-max pre-processing average: 0.55179
# ======================================================
#
# C: 0.01, Gamma: 0.001
# No pre-processing, fold 1: 0.48898
# Standard pre-processing, fold 1: 0.48809
# Min-max pre-processing, fold 1: 0.52248
#
# No pre-processing, fold 2: 0.50063
# Standard pre-processing, fold 2: 0.49854
# Min-max pre-processing, fold 2: 0.55926
#
# No pre-processing, fold 3: 0.46768
# Standard pre-processing, fold 3: 0.50625
# Min-max pre-processing, fold 3: 0.52723
#
# No pre-processing, fold 4: 0.49506
# Standard pre-processing, fold 4: 0.50834
# Min-max pre-processing, fold 4: 0.53184
#
# ======================================================
# No pre-processing average: 0.48809
# Standard pre-processing average: 0.50030
# Min-max pre-processing average: 0.53520
# ======================================================
#
# C: 0.01, Gamma: 0.01
# No pre-processing, fold 1: 0.54843
# Standard pre-processing, fold 1: 0.71416
# Min-max pre-processing, fold 1: 0.53101
#
# No pre-processing, fold 2: 0.56726
# Standard pre-processing, fold 2: 0.67273
# Min-max pre-processing, fold 2: 0.56651
#
# No pre-processing, fold 3: 0.54506
# Standard pre-processing, fold 3: 0.65688
# Min-max pre-processing, fold 3: 0.50979
#
# No pre-processing, fold 4: 0.56030
# Standard pre-processing, fold 4: 0.72529
# Min-max pre-processing, fold 4: 0.54217
#
# ======================================================
# No pre-processing average: 0.55526
# Standard pre-processing average: 0.69227
# Min-max pre-processing average: 0.53737
# ======================================================
#
# C: 0.01, Gamma: 0.1
# No pre-processing, fold 1: 0.41056
# Standard pre-processing, fold 1: 0.71041
# Min-max pre-processing, fold 1: 0.61101
#
# No pre-processing, fold 2: 0.43210
# Standard pre-processing, fold 2: 0.74319
# Min-max pre-processing, fold 2: 0.61467
#
# No pre-processing, fold 3: 0.40889
# Standard pre-processing, fold 3: 0.73373
# Min-max pre-processing, fold 3: 0.59427
#
# No pre-processing, fold 4: 0.41113
# Standard pre-processing, fold 4: 0.73368
# Min-max pre-processing, fold 4: 0.60348
#
# ======================================================
# No pre-processing average: 0.41567
# Standard pre-processing average: 0.73026
# Min-max pre-processing average: 0.60586
# ======================================================
#
# C: 0.01, Gamma: 1
# No pre-processing, fold 1: 0.12355
# Standard pre-processing, fold 1: 0.58738
# Min-max pre-processing, fold 1: 0.71541
#
# No pre-processing, fold 2: 0.12174
# Standard pre-processing, fold 2: 0.61365
# Min-max pre-processing, fold 2: 0.76234
#
# No pre-processing, fold 3: 0.12403
# Standard pre-processing, fold 3: 0.59436
# Min-max pre-processing, fold 3: 0.74078
#
# No pre-processing, fold 4: 0.12072
# Standard pre-processing, fold 4: 0.57822
# Min-max pre-processing, fold 4: 0.73759
#
# ======================================================
# No pre-processing average: 0.12251
# Standard pre-processing average: 0.59340
# Min-max pre-processing average: 0.73903
# ======================================================
#
# C: 0.01, Gamma: 10
# No pre-processing, fold 1: 0.02763
# Standard pre-processing, fold 1: 0.72279
# Min-max pre-processing, fold 1: 0.67632
#
# No pre-processing, fold 2: 0.02935
# Standard pre-processing, fold 2: 0.72420
# Min-max pre-processing, fold 2: 0.70943
#
# No pre-processing, fold 3: 0.02939
# Standard pre-processing, fold 3: 0.72503
# Min-max pre-processing, fold 3: 0.69937
#
# No pre-processing, fold 4: 0.02942
# Standard pre-processing, fold 4: 0.66236
# Min-max pre-processing, fold 4: 0.69681
#
# ======================================================
# No pre-processing average: 0.02895
# Standard pre-processing average: 0.70860
# Min-max pre-processing average: 0.69548
# ======================================================
#
# C: 0.01, Gamma: 100
# No pre-processing, fold 1: 0.02222
# Standard pre-processing, fold 1: 0.56312
# Min-max pre-processing, fold 1: 0.53994
#
# No pre-processing, fold 2: 0.02214
# Standard pre-processing, fold 2: 0.58876
# Min-max pre-processing, fold 2: 0.55463
#
# No pre-processing, fold 3: 0.02222
# Standard pre-processing, fold 3: 0.58411
# Min-max pre-processing, fold 3: 0.55438
#
# No pre-processing, fold 4: 0.02222
# Standard pre-processing, fold 4: 0.57931
# Min-max pre-processing, fold 4: 0.54915
#
# ======================================================
# No pre-processing average: 0.02220
# Standard pre-processing average: 0.57883
# Min-max pre-processing average: 0.54953
# ======================================================
#
# C: 0.1, Gamma: 0.001
# No pre-processing, fold 1: 0.48554
# Standard pre-processing, fold 1: 0.64687
# Min-max pre-processing, fold 1: 0.52642
#
# No pre-processing, fold 2: 0.49963
# Standard pre-processing, fold 2: 0.65273
# Min-max pre-processing, fold 2: 0.56057
#
# No pre-processing, fold 3: 0.46573
# Standard pre-processing, fold 3: 0.60168
# Min-max pre-processing, fold 3: 0.52966
#
# No pre-processing, fold 4: 0.49796
# Standard pre-processing, fold 4: 0.64288
# Min-max pre-processing, fold 4: 0.54538
#
# ======================================================
# No pre-processing average: 0.48722
# Standard pre-processing average: 0.63604
# Min-max pre-processing average: 0.54051
# ======================================================
#
# C: 0.1, Gamma: 0.01
# No pre-processing, fold 1: 0.54652
# Standard pre-processing, fold 1: 0.75072
# Min-max pre-processing, fold 1: 0.56975
#
# No pre-processing, fold 2: 0.56508
# Standard pre-processing, fold 2: 0.78259
# Min-max pre-processing, fold 2: 0.58100
#
# No pre-processing, fold 3: 0.49067
# Standard pre-processing, fold 3: 0.76327
# Min-max pre-processing, fold 3: 0.55198
#
# No pre-processing, fold 4: 0.51230
# Standard pre-processing, fold 4: 0.75649
# Min-max pre-processing, fold 4: 0.57164
#
# ======================================================
# No pre-processing average: 0.52864
# Standard pre-processing average: 0.76327
# Min-max pre-processing average: 0.56859
# ======================================================
#
# C: 0.1, Gamma: 0.1
# No pre-processing, fold 1: 0.41107
# Standard pre-processing, fold 1: 0.74898
# Min-max pre-processing, fold 1: 0.70089
#
# No pre-processing, fold 2: 0.43300
# Standard pre-processing, fold 2: 0.77788
# Min-max pre-processing, fold 2: 0.72168
#
# No pre-processing, fold 3: 0.41022
# Standard pre-processing, fold 3: 0.76797
# Min-max pre-processing, fold 3: 0.73083
# No pre-processing, fold 4: 0.41256
# Standard pre-processing, fold 4: 0.76084
# Min-max pre-processing, fold 4: 0.72817
#
# ======================================================
# No pre-processing average: 0.41671
# Standard pre-processing average: 0.76392
# Min-max pre-processing average: 0.72039
# ======================================================
#
# C: 0.1, Gamma: 1
# No pre-processing, fold 1: 0.12355
# Standard pre-processing, fold 1: 0.58188
# Min-max pre-processing, fold 1: 0.76451
#
# No pre-processing, fold 2: 0.12174
# Standard pre-processing, fold 2: 0.60819
# Min-max pre-processing, fold 2: 0.79305
#
# No pre-processing, fold 3: 0.12403
# Standard pre-processing, fold 3: 0.59884
# Min-max pre-processing, fold 3: 0.79002
#
# No pre-processing, fold 4: 0.12072
# Standard pre-processing, fold 4: 0.57986
# Min-max pre-processing, fold 4: 0.77996
#
# ======================================================
# No pre-processing average: 0.12251
# Standard pre-processing average: 0.59219
# Min-max pre-processing average: 0.78189
# ======================================================
#
# C: 0.1, Gamma: 10
# No pre-processing, fold 1: 0.02763
# Standard pre-processing, fold 1: 0.66881
# Min-max pre-processing, fold 1: 0.68179
#
# No pre-processing, fold 2: 0.02935
# Standard pre-processing, fold 2: 0.66391
# Min-max pre-processing, fold 2: 0.71738
#
# No pre-processing, fold 3: 0.02939
# Standard pre-processing, fold 3: 0.64891
# Min-max pre-processing, fold 3: 0.69679
#
# No pre-processing, fold 4: 0.02942
# Standard pre-processing, fold 4: 0.66585
# Min-max pre-processing, fold 4: 0.69425
#
# ======================================================
# No pre-processing average: 0.02895
# Standard pre-processing average: 0.66187
# Min-max pre-processing average: 0.69755
# ======================================================
#
# C: 0.1, Gamma: 100
# No pre-processing, fold 1: 0.02222
# Standard pre-processing, fold 1: 0.56447
# Min-max pre-processing, fold 1: 0.53814
#
# No pre-processing, fold 2: 0.02214
# Standard pre-processing, fold 2: 0.59054
# Min-max pre-processing, fold 2: 0.55958
#
# No pre-processing, fold 3: 0.02222
# Standard pre-processing, fold 3: 0.58519
# Min-max pre-processing, fold 3: 0.56110
#
# No pre-processing, fold 4: 0.02222
# Standard pre-processing, fold 4: 0.58057
# Min-max pre-processing, fold 4: 0.55146
#
# ======================================================
# No pre-processing average: 0.02220
# Standard pre-processing average: 0.58019
# Min-max pre-processing average: 0.55257
# ======================================================
#
# C: 1, Gamma: 0.001
# No pre-processing, fold 1: 0.52602
# Standard pre-processing, fold 1: 0.75935
# Min-max pre-processing, fold 1: 0.56123
#
# No pre-processing, fold 2: 0.52125
# Standard pre-processing, fold 2: 0.78126
# Min-max pre-processing, fold 2: 0.57763
#
# No pre-processing, fold 3: 0.50242
# Standard pre-processing, fold 3: 0.76345
# Min-max pre-processing, fold 3: 0.55174
#
# No pre-processing, fold 4: 0.50344
# Standard pre-processing, fold 4: 0.76627
# Min-max pre-processing, fold 4: 0.57895
#
# ======================================================
# No pre-processing average: 0.51328
# Standard pre-processing average: 0.76758
# Min-max pre-processing average: 0.56738
# ======================================================
#
# C: 1, Gamma: 0.01
# No pre-processing, fold 1: 0.50638
# Standard pre-processing, fold 1: 0.83089
# Min-max pre-processing, fold 1: 0.66178
#
# No pre-processing, fold 2: 0.51664
# Standard pre-processing, fold 2: 0.84347
# Min-max pre-processing, fold 2: 0.70063
#
# No pre-processing, fold 3: 0.49725
# Standard pre-processing, fold 3: 0.84233
# Min-max pre-processing, fold 3: 0.71615
#
# No pre-processing, fold 4: 0.51843
# Standard pre-processing, fold 4: 0.83210
# Min-max pre-processing, fold 4: 0.72563
#
# ======================================================
# No pre-processing average: 0.50968
# Standard pre-processing average: 0.83720
# Min-max pre-processing average: 0.70105
# ======================================================
#
# C: 1, Gamma: 0.1
# No pre-processing, fold 1: 0.41154
# Standard pre-processing, fold 1: 0.85987
# Min-max pre-processing, fold 1: 0.78240
#
# No pre-processing, fold 2: 0.43134
# Standard pre-processing, fold 2: 0.87593
# Min-max pre-processing, fold 2: 0.80298
#
# No pre-processing, fold 3: 0.41016
# Standard pre-processing, fold 3: 0.87742
# Min-max pre-processing, fold 3: 0.79544
#
# No pre-processing, fold 4: 0.41310
# Standard pre-processing, fold 4: 0.85690
# Min-max pre-processing, fold 4: 0.79176
#
# ======================================================
# No pre-processing average: 0.41654
# Standard pre-processing average: 0.86753
# Min-max pre-processing average: 0.79315
# ======================================================
#
# C: 1, Gamma: 1
# No pre-processing, fold 1: 0.12355
# Standard pre-processing, fold 1: 0.70693
# Min-max pre-processing, fold 1: 0.84940
#
# No pre-processing, fold 2: 0.12174
# Standard pre-processing, fold 2: 0.72994
# Min-max pre-processing, fold 2: 0.86059
#
# No pre-processing, fold 3: 0.12403
# Standard pre-processing, fold 3: 0.71819
# Min-max pre-processing, fold 3: 0.85710
#
# No pre-processing, fold 4: 0.12072
# Standard pre-processing, fold 4: 0.70739
# Min-max pre-processing, fold 4: 0.84799
#
# ======================================================
# No pre-processing average: 0.12251
# Standard pre-processing average: 0.71561
# Min-max pre-processing average: 0.85377
# ======================================================
#
# C: 1, Gamma: 10
# No pre-processing, fold 1: 0.02763
# Standard pre-processing, fold 1: 0.70202
# Min-max pre-processing, fold 1: 0.81416
#
# No pre-processing, fold 2: 0.02935
# Standard pre-processing, fold 2: 0.70410
# Min-max pre-processing, fold 2: 0.84336
#
# No pre-processing, fold 3: 0.02939
# Standard pre-processing, fold 3: 0.63781
# Min-max pre-processing, fold 3: 0.83572
#
# No pre-processing, fold 4: 0.02942
# Standard pre-processing, fold 4: 0.69884
# Min-max pre-processing, fold 4: 0.82524
#
# ======================================================
# No pre-processing average: 0.02895
# Standard pre-processing average: 0.68569
# Min-max pre-processing average: 0.82962
# ======================================================
#
# C: 1, Gamma: 100
# No pre-processing, fold 1: 0.02222
# Standard pre-processing, fold 1: 0.56536
# Min-max pre-processing, fold 1: 0.64164
#
# No pre-processing, fold 2: 0.02214
# Standard pre-processing, fold 2: 0.59160
# Min-max pre-processing, fold 2: 0.66927
#
# No pre-processing, fold 3: 0.02222
# Standard pre-processing, fold 3: 0.58638
# Min-max pre-processing, fold 3: 0.63536
#
# No pre-processing, fold 4: 0.02222
# Standard pre-processing, fold 4: 0.58148
# Min-max pre-processing, fold 4: 0.66064
#
# ======================================================
# No pre-processing average: 0.02220
# Standard pre-processing average: 0.58120
# Min-max pre-processing average: 0.65173
# ======================================================
#
# C: 10, Gamma: 0.001
# No pre-processing, fold 1: 0.48975
# Standard pre-processing, fold 1: 0.82572
# Min-max pre-processing, fold 1: 0.66846
#
# No pre-processing, fold 2: 0.48159
# Standard pre-processing, fold 2: 0.84382
# Min-max pre-processing, fold 2: 0.70712
#
# No pre-processing, fold 3: 0.46696
# Standard pre-processing, fold 3: 0.83348
# Min-max pre-processing, fold 3: 0.70839
#
# No pre-processing, fold 4: 0.50464
# Standard pre-processing, fold 4: 0.83577
# Min-max pre-processing, fold 4: 0.71301
#
# ======================================================
# No pre-processing average: 0.48573
# Standard pre-processing average: 0.83470
# Min-max pre-processing average: 0.69925
# ======================================================
#
# C: 10, Gamma: 0.01
# No pre-processing, fold 1: 0.26849
# Standard pre-processing, fold 1: 0.86179
# Min-max pre-processing, fold 1: 0.77983
#
# No pre-processing, fold 2: 0.31554
# Standard pre-processing, fold 2: 0.87910
# Min-max pre-processing, fold 2: 0.80704
#
# No pre-processing, fold 3: 0.26267
# Standard pre-processing, fold 3: 0.87661
# Min-max pre-processing, fold 3: 0.79067
#
# No pre-processing, fold 4: 0.29405
# Standard pre-processing, fold 4: 0.87368
# Min-max pre-processing, fold 4: 0.79250
#
# ======================================================
# No pre-processing average: 0.28519
# Standard pre-processing average: 0.87279
# Min-max pre-processing average: 0.79251
# ======================================================
#
# C: 10, Gamma: 0.1
# No pre-processing, fold 1: 0.10809
# Standard pre-processing, fold 1: 0.88242
# Min-max pre-processing, fold 1: 0.84049
#
# No pre-processing, fold 2: 0.10647
# Standard pre-processing, fold 2: 0.89463
# Min-max pre-processing, fold 2: 0.85632
#
# No pre-processing, fold 3: 0.13346
# Standard pre-processing, fold 3: 0.88906
# Min-max pre-processing, fold 3: 0.85108
#
# No pre-processing, fold 4: 0.10651
# Standard pre-processing, fold 4: 0.88094
# Min-max pre-processing, fold 4: 0.84702
#
# ======================================================
# No pre-processing average: 0.11363
# Standard pre-processing average: 0.88676
# Min-max pre-processing average: 0.84872
# ======================================================
#
# C: 10, Gamma: 1
# No pre-processing, fold 1: 0.02955
# Standard pre-processing, fold 1: 0.70600
# Min-max pre-processing, fold 1: 0.87803
#
# No pre-processing, fold 2: 0.03232
# Standard pre-processing, fold 2: 0.72779
# Min-max pre-processing, fold 2: 0.89122
#
# No pre-processing, fold 3: 0.03841
# Standard pre-processing, fold 3: 0.71157
# Min-max pre-processing, fold 3: 0.88751
#
# No pre-processing, fold 4: 0.03307
# Standard pre-processing, fold 4: 0.71482
# Min-max pre-processing, fold 4: 0.87883
#
# ======================================================
# No pre-processing average: 0.03334
# Standard pre-processing average: 0.71504
# Min-max pre-processing average: 0.88389
# ======================================================
#
# C: 10, Gamma: 10
# No pre-processing, fold 1: 0.02763
# Standard pre-processing, fold 1: 0.32060
# Min-max pre-processing, fold 1: 0.82975
#
# No pre-processing, fold 2: 0.02935
# Standard pre-processing, fold 2: 0.31301
# Min-max pre-processing, fold 2: 0.85215
#
# No pre-processing, fold 3: 0.02931
# Standard pre-processing, fold 3: 0.35269
# Min-max pre-processing, fold 3: 0.84057
#
# No pre-processing, fold 4: 0.02840
# Standard pre-processing, fold 4: 0.30030
# Min-max pre-processing, fold 4: 0.84092
#
# ======================================================
# No pre-processing average: 0.02867
# Standard pre-processing average: 0.32165
# Min-max pre-processing average: 0.84085
# ======================================================
#
# C: 10, Gamma: 100
# No pre-processing, fold 1: 0.02222
# Standard pre-processing, fold 1: 0.11639
# Min-max pre-processing, fold 1: 0.55708
#
# No pre-processing, fold 2: 0.02214
# Standard pre-processing, fold 2: 0.12412
# Min-max pre-processing, fold 2: 0.62907
#
# No pre-processing, fold 3: 0.02222
# Standard pre-processing, fold 3: 0.11488
# Min-max pre-processing, fold 3: 0.60025
#
# No pre-processing, fold 4: 0.02222
# Standard pre-processing, fold 4: 0.12163
# Min-max pre-processing, fold 4: 0.64234
#
# ======================================================
# No pre-processing average: 0.02220
# Standard pre-processing average: 0.11925
# Min-max pre-processing average: 0.60718
# ======================================================
#
# C: 100, Gamma: 0.001
# No pre-processing, fold 1: 0.48843
# Standard pre-processing, fold 1: 0.84285
# Min-max pre-processing, fold 1: 0.78448
#
# No pre-processing, fold 2: 0.48209
# Standard pre-processing, fold 2: 0.86800
# Min-max pre-processing, fold 2: 0.80617
#
# No pre-processing, fold 3: 0.46549
# Standard pre-processing, fold 3: 0.86336
# Min-max pre-processing, fold 3: 0.79166
#
# No pre-processing, fold 4: 0.49661
# Standard pre-processing, fold 4: 0.85697
# Min-max pre-processing, fold 4: 0.79083
#
# ======================================================
# No pre-processing average: 0.48316
# Standard pre-processing average: 0.85779
# Min-max pre-processing average: 0.79328
# ======================================================
#
# C: 100, Gamma: 0.01
# No pre-processing, fold 1: 0.26849
# Standard pre-processing, fold 1: 0.85808
# Min-max pre-processing, fold 1: 0.83167
#
# No pre-processing, fold 2: 0.31554
# Standard pre-processing, fold 2: 0.85063
# Min-max pre-processing, fold 2: 0.85502
#
# No pre-processing, fold 3: 0.26267
# Standard pre-processing, fold 3: 0.85784
# Min-max pre-processing, fold 3: 0.84311
#
# No pre-processing, fold 4: 0.29405
# Standard pre-processing, fold 4: 0.86167
# Min-max pre-processing, fold 4: 0.84077
#
# ======================================================
# No pre-processing average: 0.28519
# Standard pre-processing average: 0.85706
# Min-max pre-processing average: 0.84264
# ======================================================
#
# C: 100, Gamma: 0.1
# No pre-processing, fold 1: 0.10809
# Standard pre-processing, fold 1: 0.82315
# Min-max pre-processing, fold 1: 0.85497
#
# No pre-processing, fold 2: 0.10647
# Standard pre-processing, fold 2: 0.83042
# Min-max pre-processing, fold 2: 0.87404
#
# No pre-processing, fold 3: 0.13346
# Standard pre-processing, fold 3: 0.83237
# Min-max pre-processing, fold 3: 0.86915
#
# No pre-processing, fold 4: 0.10651
# Standard pre-processing, fold 4: 0.83414
# Min-max pre-processing, fold 4: 0.86452
#
# ======================================================
# No pre-processing average: 0.11363
# Standard pre-processing average: 0.83002
# Min-max pre-processing average: 0.86567
# ======================================================
#
# C: 100, Gamma: 1
# No pre-processing, fold 1: 0.02955
# Standard pre-processing, fold 1: 0.70600
# Min-max pre-processing, fold 1: 0.85870
#
# No pre-processing, fold 2: 0.03232
# Standard pre-processing, fold 2: 0.72779
# Min-max pre-processing, fold 2: 0.83337
#
# No pre-processing, fold 3: 0.03841
# Standard pre-processing, fold 3: 0.71157
# Min-max pre-processing, fold 3: 0.83952
#
# No pre-processing, fold 4: 0.03307
# Standard pre-processing, fold 4: 0.71482
# Min-max pre-processing, fold 4: 0.85632
#
# ======================================================
# No pre-processing average: 0.03334
# Standard pre-processing average: 0.71504
# Min-max pre-processing average: 0.84698
# ======================================================
#
# C: 100, Gamma: 10
# No pre-processing, fold 1: 0.02763
# Standard pre-processing, fold 1: 0.32060
# Min-max pre-processing, fold 1: 0.77841
#
# No pre-processing, fold 2: 0.02935
# Standard pre-processing, fold 2: 0.31301
# Min-max pre-processing, fold 2: 0.80588
#
# No pre-processing, fold 3: 0.02931
# Standard pre-processing, fold 3: 0.35269
# Min-max pre-processing, fold 3: 0.82828
#
# No pre-processing, fold 4: 0.02840
# Standard pre-processing, fold 4: 0.30030
# Min-max pre-processing, fold 4: 0.82649
#
# ======================================================
# No pre-processing average: 0.02867
# Standard pre-processing average: 0.32165
# Min-max pre-processing average: 0.80976
# ======================================================
#
# C: 100, Gamma: 100
# No pre-processing, fold 1: 0.02222
# Standard pre-processing, fold 1: 0.11639
# Min-max pre-processing, fold 1: 0.55708
#
# No pre-processing, fold 2: 0.02214
# Standard pre-processing, fold 2: 0.12412
# Min-max pre-processing, fold 2: 0.62907
#
# No pre-processing, fold 3: 0.02222
# Standard pre-processing, fold 3: 0.11488
# Min-max pre-processing, fold 3: 0.60025
#
# No pre-processing, fold 4: 0.02222
# Standard pre-processing, fold 4: 0.12163
# Min-max pre-processing, fold 4: 0.64234
#
# ======================================================
# No pre-processing average: 0.02220
# Standard pre-processing average: 0.11925
# Min-max pre-processing average: 0.60718
# ======================================================

# %%
# svm kernel:linear
from sklearn.svm import SVC

poly_deg = [1, 2, 3, 4]
gamma_val = [0.001, 0.01, 0.1, 1, 10, 100]
C_values = [0.001, 0.01, 0.1, 1, 10, 100]
kernels = ['linear']

for kernel in kernels:
    print("Kernel: {}".format(kernel))
    if kernel == 'linear':
        for c in C_values:
            svm=SVC(kernel=kernel, C=c, random_state=seed, max_iter=500)
            print("C value: {}".format(c))
            cross_val(X, y, svm, skf)
            print()
    if kernel == 'poly':
        for c in C_values:
            for deg in poly_deg:
                for gamma in gamma_val:
                    svm=SVC(kernel=kernel, C=c, degree=degree, gamma=gamma, random_state=seed, max_iter=500)
                    print("C: {0}, Degrees: {1}, Gamma: {2}".format(c, degree, gamma))
                    cross_val(X, y, svm, skf)
                    print()
    if kernel == 'rbf':
        for c in C_values:
            for gamma in gamma_val:
                svm=SVC(kernel=kernel, C=c, gamma=gamma, random_state=seed, max_iter=500)
                print("C: {0}, Gamma: {1}".format(c, gamma))
                cross_val(X, y, svm, skf)
                print()
# Out:
# Kernel: linear
# C value: 0.001
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\base.py:218: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# No pre-processing, fold 1: 0.44539
# Standard pre-processing, fold 1: 0.72182
# Min-max pre-processing, fold 1: 0.56177
#
# No pre-processing, fold 2: 0.40859
# Standard pre-processing, fold 2: 0.75592
# Min-max pre-processing, fold 2: 0.59006
#
# No pre-processing, fold 3: 0.54681
# Standard pre-processing, fold 3: 0.75292
# Min-max pre-processing, fold 3: 0.55604
#
# No pre-processing, fold 4: 0.42417
# Standard pre-processing, fold 4: 0.75147
# Min-max pre-processing, fold 4: 0.56947
#
# ======================================================
# No pre-processing average: 0.45624
# Standard pre-processing average: 0.74553
# Min-max pre-processing average: 0.56933
# ======================================================
#
# C value: 0.01
# No pre-processing, fold 1: 0.37159
# Standard pre-processing, fold 1: 0.80939
# Min-max pre-processing, fold 1: 0.66865
#
# No pre-processing, fold 2: 0.38232
# Standard pre-processing, fold 2: 0.82526
# Min-max pre-processing, fold 2: 0.67230
#
# No pre-processing, fold 3: 0.35835
# Standard pre-processing, fold 3: 0.81217
# Min-max pre-processing, fold 3: 0.60585
#
# No pre-processing, fold 4: 0.44793
# Standard pre-processing, fold 4: 0.81064
# Min-max pre-processing, fold 4: 0.62530
#
# ======================================================
# No pre-processing average: 0.39005
# Standard pre-processing average: 0.81436
# Min-max pre-processing average: 0.64302
# ======================================================
#
# C value: 0.1
# No pre-processing, fold 1: 0.45032
# Standard pre-processing, fold 1: 0.82709
# Min-max pre-processing, fold 1: 0.75767
#
# No pre-processing, fold 2: 0.40297
# Standard pre-processing, fold 2: 0.85728
# Min-max pre-processing, fold 2: 0.78762
#
# No pre-processing, fold 3: 0.35310
# Standard pre-processing, fold 3: 0.84416
# Min-max pre-processing, fold 3: 0.76388
#
# No pre-processing, fold 4: 0.39884
# Standard pre-processing, fold 4: 0.84685
# Min-max pre-processing, fold 4: 0.76772
#
# ======================================================
# No pre-processing average: 0.40131
# Standard pre-processing average: 0.84384
# Min-max pre-processing average: 0.76922
# ======================================================
#
# C value: 1
# No pre-processing, fold 1: 0.43947
# Standard pre-processing, fold 1: 0.77346
# Min-max pre-processing, fold 1: 0.81926
#
# No pre-processing, fold 2: 0.31972
# Standard pre-processing, fold 2: 0.81795
# Min-max pre-processing, fold 2: 0.84060
#
# No pre-processing, fold 3: 0.35310
# Standard pre-processing, fold 3: 0.79815
# Min-max pre-processing, fold 3: 0.82590
#
# No pre-processing, fold 4: 0.41109
# Standard pre-processing, fold 4: 0.77074
# Min-max pre-processing, fold 4: 0.83221
#
# ======================================================
# No pre-processing average: 0.38085
# Standard pre-processing average: 0.79007
# Min-max pre-processing average: 0.82950
# ======================================================
#
# C value: 10
# No pre-processing, fold 1: 0.43947
# Standard pre-processing, fold 1: 0.63467
# Min-max pre-processing, fold 1: 0.83607
#
# No pre-processing, fold 2: 0.31972
# Standard pre-processing, fold 2: 0.67208
# Min-max pre-processing, fold 2: 0.85942
#
# No pre-processing, fold 3: 0.35310
# Standard pre-processing, fold 3: 0.70170
# Min-max pre-processing, fold 3: 0.84856
#
# No pre-processing, fold 4: 0.41109
# Standard pre-processing, fold 4: 0.69505
# Min-max pre-processing, fold 4: 0.84462
#
# ======================================================
# No pre-processing average: 0.38085
# Standard pre-processing average: 0.67587
# Min-max pre-processing average: 0.84717
# ======================================================
#
# C value: 100
# No pre-processing, fold 1: 0.43947
# Standard pre-processing, fold 1: 0.64184
# Min-max pre-processing, fold 1: 0.75887
#
# No pre-processing, fold 2: 0.31972
# Standard pre-processing, fold 2: 0.63850
# Min-max pre-processing, fold 2: 0.77579
#
# No pre-processing, fold 3: 0.35310
# Standard pre-processing, fold 3: 0.64090
# Min-max pre-processing, fold 3: 0.75941
#
# No pre-processing, fold 4: 0.41109
# Standard pre-processing, fold 4: 0.65700
# Min-max pre-processing, fold 4: 0.72020
#
# ======================================================
# No pre-processing average: 0.38085
# Standard pre-processing average: 0.64456
# Min-max pre-processing average: 0.75357
# ======================================================

# %%
# svm kernel:poly
from sklearn.svm import SVC

poly_deg = [1, 2, 3, 4]
gamma_val = [0.001, 0.01, 0.1, 1, 10, 100]
C_values = [0.001, 0.01, 0.1, 1, 10, 100]
kernels = ['poly']

for kernel in kernels:
    print("Kernel: {}".format(kernel))
    if kernel == 'linear':
        for c in C_values:
            svm=SVC(kernel=kernel, C=c, random_state=seed, max_iter=500)
            print("C value: {}".format(c))
            cross_val(X, y, svm, skf)
            print()
    if kernel == 'poly':
        for c in C_values:
            for deg in poly_deg:
                for gamma in gamma_val:
                    svm=SVC(kernel=kernel, C=c, degree=deg, gamma=gamma, random_state=seed, max_iter=500)
                    print("C: {0}, Degrees: {1}, Gamma: {2}".format(c, deg, gamma))
                    cross_val(X, y, svm, skf)
                    print()
    if kernel == 'rbf':
        for c in C_values:
            for gamma in gamma_val:
                svm=SVC(kernel=kernel, C=c, gamma=gamma, random_state=seed, max_iter=500)
                print("C: {0}, Gamma: {1}".format(c, gamma))
                cross_val(X, y, svm, skf)
                print()
# Out:
# Kernel: poly
# C: 0.001, Degrees: 1, Gamma: 0.001
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\base.py:218: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# No pre-processing, fold 1: 0.55282
# Standard pre-processing, fold 1: 0.46246
# Min-max pre-processing, fold 1: 0.52629
#
# No pre-processing, fold 2: 0.55247
# Standard pre-processing, fold 2: 0.42978
# Min-max pre-processing, fold 2: 0.55789
#
# No pre-processing, fold 3: 0.54470
# Standard pre-processing, fold 3: 0.47177
# Min-max pre-processing, fold 3: 0.52418
#
# No pre-processing, fold 4: 0.51759
# Standard pre-processing, fold 4: 0.51142
# Min-max pre-processing, fold 4: 0.53025
#
# ======================================================
# No pre-processing average: 0.54189
# Standard pre-processing average: 0.46886
# Min-max pre-processing average: 0.53465
# ======================================================
#
# C: 0.001, Degrees: 1, Gamma: 0.01
# No pre-processing, fold 1: 0.61632
# Standard pre-processing, fold 1: 0.46318
# Min-max pre-processing, fold 1: 0.52392
#
# No pre-processing, fold 2: 0.57571
# Standard pre-processing, fold 2: 0.48806
# Min-max pre-processing, fold 2: 0.55789
#
# No pre-processing, fold 3: 0.56843
# Standard pre-processing, fold 3: 0.47907
# Min-max pre-processing, fold 3: 0.52460
#
# No pre-processing, fold 4: 0.54780
# Standard pre-processing, fold 4: 0.49372
# Min-max pre-processing, fold 4: 0.53025
#
# ======================================================
# No pre-processing average: 0.57707
# Standard pre-processing average: 0.48101
# Min-max pre-processing average: 0.53416
# ======================================================
#
# C: 0.001, Degrees: 1, Gamma: 0.1
# No pre-processing, fold 1: 0.56258
# Standard pre-processing, fold 1: 0.61481
# Min-max pre-processing, fold 1: 0.52434
#
# No pre-processing, fold 2: 0.52660
# Standard pre-processing, fold 2: 0.58876
# Min-max pre-processing, fold 2: 0.55914
#
# No pre-processing, fold 3: 0.46624
# Standard pre-processing, fold 3: 0.54327
# Min-max pre-processing, fold 3: 0.52265
#
# No pre-processing, fold 4: 0.49850
# Standard pre-processing, fold 4: 0.56972
# Min-max pre-processing, fold 4: 0.53634
#
# ======================================================
# No pre-processing average: 0.51348
# Standard pre-processing average: 0.57914
# Min-max pre-processing average: 0.53562
# ======================================================
#
# C: 0.001, Degrees: 1, Gamma: 1
# No pre-processing, fold 1: 0.44539
# Standard pre-processing, fold 1: 0.72182
# Min-max pre-processing, fold 1: 0.56177
#
# No pre-processing, fold 2: 0.40859
# Standard pre-processing, fold 2: 0.75592
# Min-max pre-processing, fold 2: 0.59006
#
# No pre-processing, fold 3: 0.54681
# Standard pre-processing, fold 3: 0.75292
# Min-max pre-processing, fold 3: 0.55604
#
# No pre-processing, fold 4: 0.42417
# Standard pre-processing, fold 4: 0.75147
# Min-max pre-processing, fold 4: 0.56947
#
# ======================================================
# No pre-processing average: 0.45624
# Standard pre-processing average: 0.74553
# Min-max pre-processing average: 0.56933
# ======================================================
#
# C: 0.001, Degrees: 1, Gamma: 10
# No pre-processing, fold 1: 0.37062
# Standard pre-processing, fold 1: 0.80939
# Min-max pre-processing, fold 1: 0.66865
#
# No pre-processing, fold 2: 0.30064
# Standard pre-processing, fold 2: 0.82564
# Min-max pre-processing, fold 2: 0.67235
#
# No pre-processing, fold 3: 0.41786
# Standard pre-processing, fold 3: 0.81217
# Min-max pre-processing, fold 3: 0.60537
#
# No pre-processing, fold 4: 0.34984
# Standard pre-processing, fold 4: 0.81064
# Min-max pre-processing, fold 4: 0.62530
#
# ======================================================
# No pre-processing average: 0.35974
# Standard pre-processing average: 0.81446
# Min-max pre-processing average: 0.64292
# ======================================================
#
# C: 0.001, Degrees: 1, Gamma: 100
# No pre-processing, fold 1: 0.40224
# Standard pre-processing, fold 1: 0.82672
# Min-max pre-processing, fold 1: 0.75767
#
# No pre-processing, fold 2: 0.44499
# Standard pre-processing, fold 2: 0.85680
# Min-max pre-processing, fold 2: 0.78146
#
# No pre-processing, fold 3: 0.37745
# Standard pre-processing, fold 3: 0.84619
# Min-max pre-processing, fold 3: 0.76388
#
# No pre-processing, fold 4: 0.41665
# Standard pre-processing, fold 4: 0.84728
# Min-max pre-processing, fold 4: 0.76772
#
# ======================================================
# No pre-processing average: 0.41033
# Standard pre-processing average: 0.84425
# Min-max pre-processing average: 0.76768
# ======================================================
#
# C: 0.001, Degrees: 2, Gamma: 0.001
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# No pre-processing, fold 1: 0.34698
# Standard pre-processing, fold 1: 0.33935
# Min-max pre-processing, fold 1: 0.53314
#
# No pre-processing, fold 2: 0.34580
# Standard pre-processing, fold 2: 0.38630
# Min-max pre-processing, fold 2: 0.48858
#
# No pre-processing, fold 3: 0.35905
# Standard pre-processing, fold 3: 0.32094
# Min-max pre-processing, fold 3: 0.49794
#
# No pre-processing, fold 4: 0.43438
# Standard pre-processing, fold 4: 0.34032
# Min-max pre-processing, fold 4: 0.49645
#
# ======================================================
# No pre-processing average: 0.37155
# Standard pre-processing average: 0.34673
# Min-max pre-processing average: 0.50403
# ======================================================
#
# C: 0.001, Degrees: 2, Gamma: 0.01
# No pre-processing, fold 1: 0.44781
# Standard pre-processing, fold 1: 0.34155
# Min-max pre-processing, fold 1: 0.53314
#
# No pre-processing, fold 2: 0.44469
# Standard pre-processing, fold 2: 0.38727
# Min-max pre-processing, fold 2: 0.48858
#
# No pre-processing, fold 3: 0.32566
# Standard pre-processing, fold 3: 0.32320
# Min-max pre-processing, fold 3: 0.49794
#
# No pre-processing, fold 4: 0.42921
# Standard pre-processing, fold 4: 0.34055
# Min-max pre-processing, fold 4: 0.49645
#
# ======================================================
# No pre-processing average: 0.41184
# Standard pre-processing average: 0.34814
# Min-max pre-processing average: 0.50403
# ======================================================
#
# C: 0.001, Degrees: 2, Gamma: 0.1
# No pre-processing, fold 1: 0.46046
# Standard pre-processing, fold 1: 0.58428
# Min-max pre-processing, fold 1: 0.53771
#
# No pre-processing, fold 2: 0.38240
# Standard pre-processing, fold 2: 0.57647
# Min-max pre-processing, fold 2: 0.48607
#
# No pre-processing, fold 3: 0.39376
# Standard pre-processing, fold 3: 0.57497
# Min-max pre-processing, fold 3: 0.46974
#
# No pre-processing, fold 4: 0.40223
# Standard pre-processing, fold 4: 0.60273
# Min-max pre-processing, fold 4: 0.50487
#
# ======================================================
# No pre-processing average: 0.40972
# Standard pre-processing average: 0.58461
# Min-max pre-processing average: 0.49960
# ======================================================
#
# C: 0.001, Degrees: 2, Gamma: 1
# No pre-processing, fold 1: 0.28319
# Standard pre-processing, fold 1: 0.83429
# Min-max pre-processing, fold 1: 0.65874
#
# No pre-processing, fold 2: 0.43329
# Standard pre-processing, fold 2: 0.85304
# Min-max pre-processing, fold 2: 0.66310
#
# No pre-processing, fold 3: 0.35466
# Standard pre-processing, fold 3: 0.85302
# Min-max pre-processing, fold 3: 0.66716
#
# No pre-processing, fold 4: 0.34151
# Standard pre-processing, fold 4: 0.83668
# Min-max pre-processing, fold 4: 0.70417
#
# ======================================================
# No pre-processing average: 0.35316
# Standard pre-processing average: 0.84426
# Min-max pre-processing average: 0.67329
# ======================================================
#
# C: 0.001, Degrees: 2, Gamma: 10
# No pre-processing, fold 1: 0.37023
# Standard pre-processing, fold 1: 0.80694
# Min-max pre-processing, fold 1: 0.83226
#
# No pre-processing, fold 2: 0.35294
# Standard pre-processing, fold 2: 0.80417
# Min-max pre-processing, fold 2: 0.85517
#
# No pre-processing, fold 3: 0.29753
# Standard pre-processing, fold 3: 0.80131
# Min-max pre-processing, fold 3: 0.84884
#
# No pre-processing, fold 4: 0.26369
# Standard pre-processing, fold 4: 0.79864
# Min-max pre-processing, fold 4: 0.84208
#
# ======================================================
# No pre-processing average: 0.32110
# Standard pre-processing average: 0.80277
# Min-max pre-processing average: 0.84459
# ======================================================
#
# C: 0.001, Degrees: 2, Gamma: 100
# No pre-processing, fold 1: 0.39743
# Standard pre-processing, fold 1: 0.73331
# Min-max pre-processing, fold 1: 0.74455
#
# No pre-processing, fold 2: 0.34971
# Standard pre-processing, fold 2: 0.76009
# Min-max pre-processing, fold 2: 0.75535
#
# No pre-processing, fold 3: 0.32250
# Standard pre-processing, fold 3: 0.77411
# Min-max pre-processing, fold 3: 0.74178
#
# No pre-processing, fold 4: 0.36500
# Standard pre-processing, fold 4: 0.76779
# Min-max pre-processing, fold 4: 0.71237
#
# ======================================================
# No pre-processing average: 0.35866
# Standard pre-processing average: 0.75882
# Min-max pre-processing average: 0.73851
# ======================================================
#
# C: 0.001, Degrees: 3, Gamma: 0.001
# No pre-processing, fold 1: 0.34122
# Standard pre-processing, fold 1: 0.22579
# Min-max pre-processing, fold 1: 0.46238
#
# No pre-processing, fold 2: 0.37031
# Standard pre-processing, fold 2: 0.29023
# Min-max pre-processing, fold 2: 0.44996
#
# No pre-processing, fold 3: 0.44416
# Standard pre-processing, fold 3: 0.20787
# Min-max pre-processing, fold 3: 0.47200
#
# No pre-processing, fold 4: 0.31011
# Standard pre-processing, fold 4: 0.22064
# Min-max pre-processing, fold 4: 0.45844
#
# ======================================================
# No pre-processing average: 0.36645
# Standard pre-processing average: 0.23613
# Min-max pre-processing average: 0.46069
# ======================================================
#
# C: 0.001, Degrees: 3, Gamma: 0.01
# No pre-processing, fold 1: 0.31791
# Standard pre-processing, fold 1: 0.25370
# Min-max pre-processing, fold 1: 0.46238
#
# No pre-processing, fold 2: 0.37032
# Standard pre-processing, fold 2: 0.29163
# Min-max pre-processing, fold 2: 0.44996
#
# No pre-processing, fold 3: 0.40947
# Standard pre-processing, fold 3: 0.24137
# Min-max pre-processing, fold 3: 0.47200
#
# No pre-processing, fold 4: 0.35042
# Standard pre-processing, fold 4: 0.25080
# Min-max pre-processing, fold 4: 0.45844
#
# ======================================================
# No pre-processing average: 0.36203
# Standard pre-processing average: 0.25937
# Min-max pre-processing average: 0.46069
# ======================================================
#
# C: 0.001, Degrees: 3, Gamma: 0.1
# No pre-processing, fold 1: 0.34558
# Standard pre-processing, fold 1: 0.60717
# Min-max pre-processing, fold 1: 0.46503
#
# No pre-processing, fold 2: 0.41489
# Standard pre-processing, fold 2: 0.59235
# Min-max pre-processing, fold 2: 0.47265
#
# No pre-processing, fold 3: 0.36791
# Standard pre-processing, fold 3: 0.61513
# Min-max pre-processing, fold 3: 0.47647
#
# No pre-processing, fold 4: 0.43988
# Standard pre-processing, fold 4: 0.63092
# Min-max pre-processing, fold 4: 0.46488
#
# ======================================================
# No pre-processing average: 0.39207
# Standard pre-processing average: 0.61139
# Min-max pre-processing average: 0.46976
# ======================================================
#
# C: 0.001, Degrees: 3, Gamma: 1
# No pre-processing, fold 1: 0.33856
# Standard pre-processing, fold 1: 0.81655
# Min-max pre-processing, fold 1: 0.78648
#
# No pre-processing, fold 2: 0.35480
# Standard pre-processing, fold 2: 0.85281
# Min-max pre-processing, fold 2: 0.80598
#
# No pre-processing, fold 3: 0.33784
# Standard pre-processing, fold 3: 0.84693
# Min-max pre-processing, fold 3: 0.79670
#
# No pre-processing, fold 4: 0.34829
# Standard pre-processing, fold 4: 0.84611
# Min-max pre-processing, fold 4: 0.79046
#
# ======================================================
# No pre-processing average: 0.34487
# Standard pre-processing average: 0.84060
# Min-max pre-processing average: 0.79490
# ======================================================
#
# C: 0.001, Degrees: 3, Gamma: 10
# No pre-processing, fold 1: 0.41903
# Standard pre-processing, fold 1: 0.77100
# Min-max pre-processing, fold 1: 0.73021
#
# No pre-processing, fold 2: 0.32132
# Standard pre-processing, fold 2: 0.78665
# Min-max pre-processing, fold 2: 0.71680
#
# No pre-processing, fold 3: 0.34975
# Standard pre-processing, fold 3: 0.77405
# Min-max pre-processing, fold 3: 0.74907
#
# No pre-processing, fold 4: 0.32698
# Standard pre-processing, fold 4: 0.78532
# Min-max pre-processing, fold 4: 0.76445
#
# ======================================================
# No pre-processing average: 0.35427
# Standard pre-processing average: 0.77925
# Min-max pre-processing average: 0.74013
# ======================================================
#
# C: 0.001, Degrees: 3, Gamma: 100
# No pre-processing, fold 1: 0.33100
# Standard pre-processing, fold 1: 0.77352
# Min-max pre-processing, fold 1: 0.72181
#
# No pre-processing, fold 2: 0.38502
# Standard pre-processing, fold 2: 0.78955
# Min-max pre-processing, fold 2: 0.69790
#
# No pre-processing, fold 3: 0.40900
# Standard pre-processing, fold 3: 0.76876
# Min-max pre-processing, fold 3: 0.69411
#
# No pre-processing, fold 4: 0.37774
# Standard pre-processing, fold 4: 0.77750
# Min-max pre-processing, fold 4: 0.73324
#
# ======================================================
# No pre-processing average: 0.37569
# Standard pre-processing average: 0.77733
# Min-max pre-processing average: 0.71176
# ======================================================
#
# C: 0.001, Degrees: 4, Gamma: 0.001
# No pre-processing, fold 1: 0.38382
# Standard pre-processing, fold 1: 0.29325
# Min-max pre-processing, fold 1: 0.42050
#
# No pre-processing, fold 2: 0.33323
# Standard pre-processing, fold 2: 0.32577
# Min-max pre-processing, fold 2: 0.40673
#
# No pre-processing, fold 3: 0.29623
# Standard pre-processing, fold 3: 0.27231
# Min-max pre-processing, fold 3: 0.41743
#
# No pre-processing, fold 4: 0.26662
# Standard pre-processing, fold 4: 0.27772
# Min-max pre-processing, fold 4: 0.42235
#
# ======================================================
# No pre-processing average: 0.31998
# Standard pre-processing average: 0.29226
# Min-max pre-processing average: 0.41675
# ======================================================
#
# C: 0.001, Degrees: 4, Gamma: 0.01
# No pre-processing, fold 1: 0.39590
# Standard pre-processing, fold 1: 0.29399
# Min-max pre-processing, fold 1: 0.42449
#
# No pre-processing, fold 2: 0.40526
# Standard pre-processing, fold 2: 0.32570
# Min-max pre-processing, fold 2: 0.40854
#
# No pre-processing, fold 3: 0.25164
# Standard pre-processing, fold 3: 0.27118
# Min-max pre-processing, fold 3: 0.42525
#
# No pre-processing, fold 4: 0.34011
# Standard pre-processing, fold 4: 0.27724
# Min-max pre-processing, fold 4: 0.42447
#
# ======================================================
# No pre-processing average: 0.34823
# Standard pre-processing average: 0.29203
# Min-max pre-processing average: 0.42069
# ======================================================
#
# C: 0.001, Degrees: 4, Gamma: 0.1
# No pre-processing, fold 1: 0.44982
# Standard pre-processing, fold 1: 0.59987
# Min-max pre-processing, fold 1: 0.43978
#
# No pre-processing, fold 2: 0.30051
# Standard pre-processing, fold 2: 0.66808
# Min-max pre-processing, fold 2: 0.43351
#
# No pre-processing, fold 3: 0.28945
# Standard pre-processing, fold 3: 0.62411
# Min-max pre-processing, fold 3: 0.43341
#
# No pre-processing, fold 4: 0.34979
# Standard pre-processing, fold 4: 0.61196
# Min-max pre-processing, fold 4: 0.42726
#
# ======================================================
# No pre-processing average: 0.34739
# Standard pre-processing average: 0.62600
# Min-max pre-processing average: 0.43349
# ======================================================
#
# C: 0.001, Degrees: 4, Gamma: 1
# No pre-processing, fold 1: 0.33104
# Standard pre-processing, fold 1: 0.75102
# Min-max pre-processing, fold 1: 0.84149
#
# No pre-processing, fold 2: 0.40986
# Standard pre-processing, fold 2: 0.81707
# Min-max pre-processing, fold 2: 0.85866
#
# No pre-processing, fold 3: 0.31360
# Standard pre-processing, fold 3: 0.76637
# Min-max pre-processing, fold 3: 0.85508
#
# No pre-processing, fold 4: 0.34438
# Standard pre-processing, fold 4: 0.75415
# Min-max pre-processing, fold 4: 0.84596
#
# ======================================================
# No pre-processing average: 0.34972
# Standard pre-processing average: 0.77215
# Min-max pre-processing average: 0.85030
# ======================================================
#
# C: 0.001, Degrees: 4, Gamma: 10
# No pre-processing, fold 1: 0.33595
# Standard pre-processing, fold 1: 0.74968
# Min-max pre-processing, fold 1: 0.73074
#
# No pre-processing, fold 2: 0.39381
# Standard pre-processing, fold 2: 0.81907
# Min-max pre-processing, fold 2: 0.74755
#
# No pre-processing, fold 3: 0.35419
# Standard pre-processing, fold 3: 0.78636
# Min-max pre-processing, fold 3: 0.71047
#
# No pre-processing, fold 4: 0.26560
# Standard pre-processing, fold 4: 0.78395
# Min-max pre-processing, fold 4: 0.73463
#
# ======================================================
# No pre-processing average: 0.33739
# Standard pre-processing average: 0.78477
# Min-max pre-processing average: 0.73085
# ======================================================
#
# C: 0.001, Degrees: 4, Gamma: 100
# No pre-processing, fold 1: 0.14163
# Standard pre-processing, fold 1: 0.75207
# Min-max pre-processing, fold 1: 0.70927
#
# No pre-processing, fold 2: 0.21724
# Standard pre-processing, fold 2: 0.81651
# Min-max pre-processing, fold 2: 0.74324
#
# No pre-processing, fold 3: 0.16748
# Standard pre-processing, fold 3: 0.78253
# Min-max pre-processing, fold 3: 0.70961
#
# No pre-processing, fold 4: 0.16940
# Standard pre-processing, fold 4: 0.73750
# Min-max pre-processing, fold 4: 0.71943
#
# ======================================================
# No pre-processing average: 0.17394
# Standard pre-processing average: 0.77215
# Min-max pre-processing average: 0.72039
# ======================================================
#
# C: 0.01, Degrees: 1, Gamma: 0.001
# No pre-processing, fold 1: 0.58613
# Standard pre-processing, fold 1: 0.46318
# Min-max pre-processing, fold 1: 0.52382
#
# No pre-processing, fold 2: 0.61386
# Standard pre-processing, fold 2: 0.48806
# Min-max pre-processing, fold 2: 0.55789
#
# No pre-processing, fold 3: 0.59778
# Standard pre-processing, fold 3: 0.47907
# Min-max pre-processing, fold 3: 0.52435
#
# No pre-processing, fold 4: 0.60001
# Standard pre-processing, fold 4: 0.49372
# Min-max pre-processing, fold 4: 0.53025
#
# ======================================================
# No pre-processing average: 0.59945
# Standard pre-processing average: 0.48101
# Min-max pre-processing average: 0.53408
# ======================================================
#
# C: 0.01, Degrees: 1, Gamma: 0.01
# No pre-processing, fold 1: 0.49724
# Standard pre-processing, fold 1: 0.61481
# Min-max pre-processing, fold 1: 0.52425
#
# No pre-processing, fold 2: 0.56657
# Standard pre-processing, fold 2: 0.58876
# Min-max pre-processing, fold 2: 0.55914
#
# No pre-processing, fold 3: 0.46454
# Standard pre-processing, fold 3: 0.54327
# Min-max pre-processing, fold 3: 0.52290
#
# No pre-processing, fold 4: 0.52155
# Standard pre-processing, fold 4: 0.56972
# Min-max pre-processing, fold 4: 0.53634
#
# ======================================================
# No pre-processing average: 0.51247
# Standard pre-processing average: 0.57914
# Min-max pre-processing average: 0.53565
# ======================================================
#
# C: 0.01, Degrees: 1, Gamma: 0.1
# No pre-processing, fold 1: 0.42595
# Standard pre-processing, fold 1: 0.72182
# Min-max pre-processing, fold 1: 0.56177
#
# No pre-processing, fold 2: 0.40471
# Standard pre-processing, fold 2: 0.75592
# Min-max pre-processing, fold 2: 0.59006
#
# No pre-processing, fold 3: 0.45340
# Standard pre-processing, fold 3: 0.75335
# Min-max pre-processing, fold 3: 0.55501
#
# No pre-processing, fold 4: 0.43635
# Standard pre-processing, fold 4: 0.75147
# Min-max pre-processing, fold 4: 0.56947
#
# ======================================================
# No pre-processing average: 0.43010
# Standard pre-processing average: 0.74564
# Min-max pre-processing average: 0.56908
# ======================================================
#
# C: 0.01, Degrees: 1, Gamma: 1
# No pre-processing, fold 1: 0.37159
# Standard pre-processing, fold 1: 0.80939
# Min-max pre-processing, fold 1: 0.66865
#
# No pre-processing, fold 2: 0.38232
# Standard pre-processing, fold 2: 0.82526
# Min-max pre-processing, fold 2: 0.67230
#
# No pre-processing, fold 3: 0.35835
# Standard pre-processing, fold 3: 0.81217
# Min-max pre-processing, fold 3: 0.60585
#
# No pre-processing, fold 4: 0.44793
# Standard pre-processing, fold 4: 0.81064
# Min-max pre-processing, fold 4: 0.62530
#
# ======================================================
# No pre-processing average: 0.39005
# Standard pre-processing average: 0.81436
# Min-max pre-processing average: 0.64302
# ======================================================
#
# C: 0.01, Degrees: 1, Gamma: 10
# No pre-processing, fold 1: 0.39588
# Standard pre-processing, fold 1: 0.82894
# Min-max pre-processing, fold 1: 0.75767
#
# No pre-processing, fold 2: 0.30484
# Standard pre-processing, fold 2: 0.85722
# Min-max pre-processing, fold 2: 0.78762
#
# No pre-processing, fold 3: 0.43336
# Standard pre-processing, fold 3: 0.84474
# Min-max pre-processing, fold 3: 0.76388
#
# No pre-processing, fold 4: 0.38850
# Standard pre-processing, fold 4: 0.84552
# Min-max pre-processing, fold 4: 0.76772
#
# ======================================================
# No pre-processing average: 0.38065
# Standard pre-processing average: 0.84410
# Min-max pre-processing average: 0.76922
# ======================================================
#
# C: 0.01, Degrees: 1, Gamma: 100
# No pre-processing, fold 1: 0.39658
# Standard pre-processing, fold 1: 0.77232
# Min-max pre-processing, fold 1: 0.81928
#
# No pre-processing, fold 2: 0.42210
# Standard pre-processing, fold 2: 0.81759
# Min-max pre-processing, fold 2: 0.84060
#
# No pre-processing, fold 3: 0.38940
# Standard pre-processing, fold 3: 0.79761
# Min-max pre-processing, fold 3: 0.82595
#
# No pre-processing, fold 4: 0.41105
# Standard pre-processing, fold 4: 0.77083
# Min-max pre-processing, fold 4: 0.83221
#
# ======================================================
# No pre-processing average: 0.40478
# Standard pre-processing average: 0.78959
# Min-max pre-processing average: 0.82951
# ======================================================
#
# C: 0.01, Degrees: 2, Gamma: 0.001
# No pre-processing, fold 1: 0.44495
# Standard pre-processing, fold 1: 0.34001
# Min-max pre-processing, fold 1: 0.53314
#
# No pre-processing, fold 2: 0.37008
# Standard pre-processing, fold 2: 0.38630
# Min-max pre-processing, fold 2: 0.48858
#
# No pre-processing, fold 3: 0.34127
# Standard pre-processing, fold 3: 0.32206
# Min-max pre-processing, fold 3: 0.49794
#
# No pre-processing, fold 4: 0.47548
# Standard pre-processing, fold 4: 0.34032
# Min-max pre-processing, fold 4: 0.49645
#
# ======================================================
# No pre-processing average: 0.40795
# Standard pre-processing average: 0.34717
# Min-max pre-processing average: 0.50403
# ======================================================
#
# C: 0.01, Degrees: 2, Gamma: 0.01
# No pre-processing, fold 1: 0.44781
# Standard pre-processing, fold 1: 0.40285
# Min-max pre-processing, fold 1: 0.53389
#
# No pre-processing, fold 2: 0.44469
# Standard pre-processing, fold 2: 0.44533
# Min-max pre-processing, fold 2: 0.48858
#
# No pre-processing, fold 3: 0.32566
# Standard pre-processing, fold 3: 0.35891
# Min-max pre-processing, fold 3: 0.50138
#
# No pre-processing, fold 4: 0.42921
# Standard pre-processing, fold 4: 0.40644
# Min-max pre-processing, fold 4: 0.49781
#
# ======================================================
# No pre-processing average: 0.41184
# Standard pre-processing average: 0.40338
# Min-max pre-processing average: 0.50541
# ======================================================
#
# C: 0.01, Degrees: 2, Gamma: 0.1
# No pre-processing, fold 1: 0.46046
# Standard pre-processing, fold 1: 0.69249
# Min-max pre-processing, fold 1: 0.53936
#
# No pre-processing, fold 2: 0.38240
# Standard pre-processing, fold 2: 0.75605
# Min-max pre-processing, fold 2: 0.56886
#
# No pre-processing, fold 3: 0.39376
# Standard pre-processing, fold 3: 0.75176
# Min-max pre-processing, fold 3: 0.52742
#
# No pre-processing, fold 4: 0.40223
# Standard pre-processing, fold 4: 0.69473
# Min-max pre-processing, fold 4: 0.54976
#
# ======================================================
# No pre-processing average: 0.40972
# Standard pre-processing average: 0.72376
# Min-max pre-processing average: 0.54635
# ======================================================
#
# C: 0.01, Degrees: 2, Gamma: 1
# No pre-processing, fold 1: 0.28319
# Standard pre-processing, fold 1: 0.85432
# Min-max pre-processing, fold 1: 0.77798
#
# No pre-processing, fold 2: 0.43329
# Standard pre-processing, fold 2: 0.87825
# Min-max pre-processing, fold 2: 0.79875
#
# No pre-processing, fold 3: 0.35466
# Standard pre-processing, fold 3: 0.86876
# Min-max pre-processing, fold 3: 0.78833
#
# No pre-processing, fold 4: 0.34151
# Standard pre-processing, fold 4: 0.87085
# Min-max pre-processing, fold 4: 0.78357
#
# ======================================================
# No pre-processing average: 0.35316
# Standard pre-processing average: 0.86804
# Min-max pre-processing average: 0.78716
# ======================================================
#
# C: 0.01, Degrees: 2, Gamma: 10
# No pre-processing, fold 1: 0.37023
# Standard pre-processing, fold 1: 0.74545
# Min-max pre-processing, fold 1: 0.83799
#
# No pre-processing, fold 2: 0.35294
# Standard pre-processing, fold 2: 0.77048
# Min-max pre-processing, fold 2: 0.86979
#
# No pre-processing, fold 3: 0.29753
# Standard pre-processing, fold 3: 0.77699
# Min-max pre-processing, fold 3: 0.85188
#
# No pre-processing, fold 4: 0.26369
# Standard pre-processing, fold 4: 0.77683
# Min-max pre-processing, fold 4: 0.85637
#
# ======================================================
# No pre-processing average: 0.32110
# Standard pre-processing average: 0.76744
# Min-max pre-processing average: 0.85401
# ======================================================
#
# C: 0.01, Degrees: 2, Gamma: 100
# No pre-processing, fold 1: 0.39743
# Standard pre-processing, fold 1: 0.73331
# Min-max pre-processing, fold 1: 0.66481
#
# No pre-processing, fold 2: 0.34971
# Standard pre-processing, fold 2: 0.76009
# Min-max pre-processing, fold 2: 0.70171
#
# No pre-processing, fold 3: 0.32250
# Standard pre-processing, fold 3: 0.77411
# Min-max pre-processing, fold 3: 0.67242
#
# No pre-processing, fold 4: 0.36500
# Standard pre-processing, fold 4: 0.76779
# Min-max pre-processing, fold 4: 0.67141
#
# ======================================================
# No pre-processing average: 0.35866
# Standard pre-processing average: 0.75882
# Min-max pre-processing average: 0.67759
# ======================================================
#
# C: 0.01, Degrees: 3, Gamma: 0.001
# No pre-processing, fold 1: 0.34122
# Standard pre-processing, fold 1: 0.22579
# Min-max pre-processing, fold 1: 0.46238
#
# No pre-processing, fold 2: 0.37031
# Standard pre-processing, fold 2: 0.29023
# Min-max pre-processing, fold 2: 0.44996
#
# No pre-processing, fold 3: 0.44416
# Standard pre-processing, fold 3: 0.20787
# Min-max pre-processing, fold 3: 0.47200
#
# No pre-processing, fold 4: 0.31011
# Standard pre-processing, fold 4: 0.22064
# Min-max pre-processing, fold 4: 0.45844
#
# ======================================================
# No pre-processing average: 0.36645
# Standard pre-processing average: 0.23613
# Min-max pre-processing average: 0.46069
# ======================================================
#
# C: 0.01, Degrees: 3, Gamma: 0.01
# No pre-processing, fold 1: 0.31791
# Standard pre-processing, fold 1: 0.27302
# Min-max pre-processing, fold 1: 0.46238
#
# No pre-processing, fold 2: 0.37032
# Standard pre-processing, fold 2: 0.30506
# Min-max pre-processing, fold 2: 0.44996
#
# No pre-processing, fold 3: 0.40947
# Standard pre-processing, fold 3: 0.25834
# Min-max pre-processing, fold 3: 0.47200
#
# No pre-processing, fold 4: 0.35042
# Standard pre-processing, fold 4: 0.27596
# Min-max pre-processing, fold 4: 0.45844
#
# ======================================================
# No pre-processing average: 0.36203
# Standard pre-processing average: 0.27810
# Min-max pre-processing average: 0.46069
# ======================================================
#
# C: 0.01, Degrees: 3, Gamma: 0.1
# No pre-processing, fold 1: 0.34558
# Standard pre-processing, fold 1: 0.78216
# Min-max pre-processing, fold 1: 0.53027
#
# No pre-processing, fold 2: 0.41489
# Standard pre-processing, fold 2: 0.78553
# Min-max pre-processing, fold 2: 0.53003
#
# No pre-processing, fold 3: 0.36791
# Standard pre-processing, fold 3: 0.79886
# Min-max pre-processing, fold 3: 0.50944
#
# No pre-processing, fold 4: 0.43988
# Standard pre-processing, fold 4: 0.78529
# Min-max pre-processing, fold 4: 0.52848
#
# ======================================================
# No pre-processing average: 0.39207
# Standard pre-processing average: 0.78796
# Min-max pre-processing average: 0.52455
# ======================================================
#
# C: 0.01, Degrees: 3, Gamma: 1
# No pre-processing, fold 1: 0.33856
# Standard pre-processing, fold 1: 0.76805
# Min-max pre-processing, fold 1: 0.83743
#
# No pre-processing, fold 2: 0.35480
# Standard pre-processing, fold 2: 0.79474
# Min-max pre-processing, fold 2: 0.85644
#
# No pre-processing, fold 3: 0.33784
# Standard pre-processing, fold 3: 0.76728
# Min-max pre-processing, fold 3: 0.85377
#
# No pre-processing, fold 4: 0.34829
# Standard pre-processing, fold 4: 0.79780
# Min-max pre-processing, fold 4: 0.84839
#
# ======================================================
# No pre-processing average: 0.34487
# Standard pre-processing average: 0.78197
# Min-max pre-processing average: 0.84901
# ======================================================
#
# C: 0.01, Degrees: 3, Gamma: 10
# No pre-processing, fold 1: 0.41903
# Standard pre-processing, fold 1: 0.77100
# Min-max pre-processing, fold 1: 0.70198
#
# No pre-processing, fold 2: 0.32132
# Standard pre-processing, fold 2: 0.78665
# Min-max pre-processing, fold 2: 0.70988
#
# No pre-processing, fold 3: 0.34975
# Standard pre-processing, fold 3: 0.77405
# Min-max pre-processing, fold 3: 0.72184
#
# No pre-processing, fold 4: 0.32698
# Standard pre-processing, fold 4: 0.78532
# Min-max pre-processing, fold 4: 0.73966
#
# ======================================================
# No pre-processing average: 0.35427
# Standard pre-processing average: 0.77925
# Min-max pre-processing average: 0.71834
# ======================================================
#
# C: 0.01, Degrees: 3, Gamma: 100
# No pre-processing, fold 1: 0.33100
# Standard pre-processing, fold 1: 0.77352
# Min-max pre-processing, fold 1: 0.72181
#
# No pre-processing, fold 2: 0.38502
# Standard pre-processing, fold 2: 0.78955
# Min-max pre-processing, fold 2: 0.69790
#
# No pre-processing, fold 3: 0.40900
# Standard pre-processing, fold 3: 0.76876
# Min-max pre-processing, fold 3: 0.69411
#
# No pre-processing, fold 4: 0.37774
# Standard pre-processing, fold 4: 0.77862
# Min-max pre-processing, fold 4: 0.73324
#
# ======================================================
# No pre-processing average: 0.37569
# Standard pre-processing average: 0.77761
# Min-max pre-processing average: 0.71176
# ======================================================
#
# C: 0.01, Degrees: 4, Gamma: 0.001
# No pre-processing, fold 1: 0.38382
# Standard pre-processing, fold 1: 0.29325
# Min-max pre-processing, fold 1: 0.42297
#
# No pre-processing, fold 2: 0.33323
# Standard pre-processing, fold 2: 0.32577
# Min-max pre-processing, fold 2: 0.40775
#
# No pre-processing, fold 3: 0.29623
# Standard pre-processing, fold 3: 0.27231
# Min-max pre-processing, fold 3: 0.42525
#
# No pre-processing, fold 4: 0.26662
# Standard pre-processing, fold 4: 0.27772
# Min-max pre-processing, fold 4: 0.42447
#
# ======================================================
# No pre-processing average: 0.31998
# Standard pre-processing average: 0.29226
# Min-max pre-processing average: 0.42011
# ======================================================
#
# C: 0.01, Degrees: 4, Gamma: 0.01
# No pre-processing, fold 1: 0.39590
# Standard pre-processing, fold 1: 0.32818
# Min-max pre-processing, fold 1: 0.42449
#
# No pre-processing, fold 2: 0.40526
# Standard pre-processing, fold 2: 0.33452
# Min-max pre-processing, fold 2: 0.40892
#
# No pre-processing, fold 3: 0.25164
# Standard pre-processing, fold 3: 0.30492
# Min-max pre-processing, fold 3: 0.42525
#
# No pre-processing, fold 4: 0.34011
# Standard pre-processing, fold 4: 0.30597
# Min-max pre-processing, fold 4: 0.42447
#
# ======================================================
# No pre-processing average: 0.34823
# Standard pre-processing average: 0.31840
# Min-max pre-processing average: 0.42078
# ======================================================
#
# C: 0.01, Degrees: 4, Gamma: 0.1
# No pre-processing, fold 1: 0.44982
# Standard pre-processing, fold 1: 0.78574
# Min-max pre-processing, fold 1: 0.50712
#
# No pre-processing, fold 2: 0.30051
# Standard pre-processing, fold 2: 0.81055
# Min-max pre-processing, fold 2: 0.53112
#
# No pre-processing, fold 3: 0.28945
# Standard pre-processing, fold 3: 0.80817
# Min-max pre-processing, fold 3: 0.48071
#
# No pre-processing, fold 4: 0.34979
# Standard pre-processing, fold 4: 0.79408
# Min-max pre-processing, fold 4: 0.50918
#
# ======================================================
# No pre-processing average: 0.34739
# Standard pre-processing average: 0.79963
# Min-max pre-processing average: 0.50703
# ======================================================
#
# C: 0.01, Degrees: 4, Gamma: 1
# No pre-processing, fold 1: 0.33104
# Standard pre-processing, fold 1: 0.75097
# Min-max pre-processing, fold 1: 0.85350
#
# No pre-processing, fold 2: 0.40986
# Standard pre-processing, fold 2: 0.81787
# Min-max pre-processing, fold 2: 0.85768
#
# No pre-processing, fold 3: 0.31360
# Standard pre-processing, fold 3: 0.77019
# Min-max pre-processing, fold 3: 0.86341
#
# No pre-processing, fold 4: 0.34438
# Standard pre-processing, fold 4: 0.77828
# Min-max pre-processing, fold 4: 0.86404
#
# ======================================================
# No pre-processing average: 0.34972
# Standard pre-processing average: 0.77933
# Min-max pre-processing average: 0.85966
# ======================================================
#
# C: 0.01, Degrees: 4, Gamma: 10
# No pre-processing, fold 1: 0.33595
# Standard pre-processing, fold 1: 0.74968
# Min-max pre-processing, fold 1: 0.73074
#
# No pre-processing, fold 2: 0.39381
# Standard pre-processing, fold 2: 0.81907
# Min-max pre-processing, fold 2: 0.74755
#
# No pre-processing, fold 3: 0.35419
# Standard pre-processing, fold 3: 0.78636
# Min-max pre-processing, fold 3: 0.71047
#
# No pre-processing, fold 4: 0.26560
# Standard pre-processing, fold 4: 0.78395
# Min-max pre-processing, fold 4: 0.73463
#
# ======================================================
# No pre-processing average: 0.33739
# Standard pre-processing average: 0.78477
# Min-max pre-processing average: 0.73085
# ======================================================
#
# C: 0.01, Degrees: 4, Gamma: 100
# No pre-processing, fold 1: 0.14356
# Standard pre-processing, fold 1: 0.74958
# Min-max pre-processing, fold 1: 0.70203
#
# No pre-processing, fold 2: 0.21646
# Standard pre-processing, fold 2: 0.81651
# Min-max pre-processing, fold 2: 0.74324
#
# No pre-processing, fold 3: 0.16657
# Standard pre-processing, fold 3: 0.77851
# Min-max pre-processing, fold 3: 0.70961
#
# No pre-processing, fold 4: 0.16755
# Standard pre-processing, fold 4: 0.73750
# Min-max pre-processing, fold 4: 0.71943
#
# ======================================================
# No pre-processing average: 0.17354
# Standard pre-processing average: 0.77052
# Min-max pre-processing average: 0.71858
# ======================================================
#
# C: 0.1, Degrees: 1, Gamma: 0.001
# No pre-processing, fold 1: 0.51817
# Standard pre-processing, fold 1: 0.61481
# Min-max pre-processing, fold 1: 0.52434
#
# No pre-processing, fold 2: 0.42901
# Standard pre-processing, fold 2: 0.58876
# Min-max pre-processing, fold 2: 0.55914
#
# No pre-processing, fold 3: 0.45028
# Standard pre-processing, fold 3: 0.54327
# Min-max pre-processing, fold 3: 0.52265
#
# No pre-processing, fold 4: 0.56080
# Standard pre-processing, fold 4: 0.56972
# Min-max pre-processing, fold 4: 0.53634
#
# ======================================================
# No pre-processing average: 0.48956
# Standard pre-processing average: 0.57914
# Min-max pre-processing average: 0.53562
# ======================================================
#
# C: 0.1, Degrees: 1, Gamma: 0.01
# No pre-processing, fold 1: 0.43786
# Standard pre-processing, fold 1: 0.72224
# Min-max pre-processing, fold 1: 0.56232
#
# No pre-processing, fold 2: 0.46598
# Standard pre-processing, fold 2: 0.75592
# Min-max pre-processing, fold 2: 0.59006
#
# No pre-processing, fold 3: 0.32879
# Standard pre-processing, fold 3: 0.75335
# Min-max pre-processing, fold 3: 0.55604
#
# No pre-processing, fold 4: 0.39269
# Standard pre-processing, fold 4: 0.75147
# Min-max pre-processing, fold 4: 0.56981
#
# ======================================================
# No pre-processing average: 0.40633
# Standard pre-processing average: 0.74574
# Min-max pre-processing average: 0.56956
# ======================================================
#
# C: 0.1, Degrees: 1, Gamma: 0.1
# No pre-processing, fold 1: 0.37211
# Standard pre-processing, fold 1: 0.80939
# Min-max pre-processing, fold 1: 0.66865
#
# No pre-processing, fold 2: 0.38130
# Standard pre-processing, fold 2: 0.82564
# Min-max pre-processing, fold 2: 0.67278
#
# No pre-processing, fold 3: 0.42021
# Standard pre-processing, fold 3: 0.81217
# Min-max pre-processing, fold 3: 0.60585
#
# No pre-processing, fold 4: 0.42701
# Standard pre-processing, fold 4: 0.81154
# Min-max pre-processing, fold 4: 0.62530
#
# ======================================================
# No pre-processing average: 0.40016
# Standard pre-processing average: 0.81468
# Min-max pre-processing average: 0.64314
# ======================================================
#
# C: 0.1, Degrees: 1, Gamma: 1
# No pre-processing, fold 1: 0.45032
# Standard pre-processing, fold 1: 0.82709
# Min-max pre-processing, fold 1: 0.75767
#
# No pre-processing, fold 2: 0.40297
# Standard pre-processing, fold 2: 0.85728
# Min-max pre-processing, fold 2: 0.78762
# No pre-processing, fold 3: 0.35310
# Standard pre-processing, fold 3: 0.84416
# Min-max pre-processing, fold 3: 0.76388
#
# No pre-processing, fold 4: 0.39884
# Standard pre-processing, fold 4: 0.84685
# Min-max pre-processing, fold 4: 0.76772
#
# ======================================================
# No pre-processing average: 0.40131
# Standard pre-processing average: 0.84384
# Min-max pre-processing average: 0.76922
# ======================================================
#
# C: 0.1, Degrees: 1, Gamma: 10
# No pre-processing, fold 1: 0.38702
# Standard pre-processing, fold 1: 0.77366
# Min-max pre-processing, fold 1: 0.81926
#
# No pre-processing, fold 2: 0.29182
# Standard pre-processing, fold 2: 0.83040
# Min-max pre-processing, fold 2: 0.84063
#
# No pre-processing, fold 3: 0.45202
# Standard pre-processing, fold 3: 0.79777
# Min-max pre-processing, fold 3: 0.82590
#
# No pre-processing, fold 4: 0.36203
# Standard pre-processing, fold 4: 0.77746
# Min-max pre-processing, fold 4: 0.83217
#
# ======================================================
# No pre-processing average: 0.37322
# Standard pre-processing average: 0.79482
# Min-max pre-processing average: 0.82949
# ======================================================
#
# C: 0.1, Degrees: 1, Gamma: 100
# No pre-processing, fold 1: 0.39658
# Standard pre-processing, fold 1: 0.64523
# Min-max pre-processing, fold 1: 0.83556
#
# No pre-processing, fold 2: 0.42210
# Standard pre-processing, fold 2: 0.66343
# Min-max pre-processing, fold 2: 0.86085
#
# No pre-processing, fold 3: 0.38940
# Standard pre-processing, fold 3: 0.70774
# Min-max pre-processing, fold 3: 0.84605
#
# No pre-processing, fold 4: 0.41105
# Standard pre-processing, fold 4: 0.69048
# Min-max pre-processing, fold 4: 0.84794
#
# ======================================================
# No pre-processing average: 0.40478
# Standard pre-processing average: 0.67672
# Min-max pre-processing average: 0.84760
# ======================================================
#
# C: 0.1, Degrees: 2, Gamma: 0.001
# No pre-processing, fold 1: 0.43318
# Standard pre-processing, fold 1: 0.34155
# Min-max pre-processing, fold 1: 0.53314
#
# No pre-processing, fold 2: 0.37008
# Standard pre-processing, fold 2: 0.38727
# Min-max pre-processing, fold 2: 0.48858
#
# No pre-processing, fold 3: 0.31330
# Standard pre-processing, fold 3: 0.32320
# Min-max pre-processing, fold 3: 0.49794
#
# No pre-processing, fold 4: 0.47293
# Standard pre-processing, fold 4: 0.34055
# Min-max pre-processing, fold 4: 0.49645
#
# ======================================================
# No pre-processing average: 0.39737
# Standard pre-processing average: 0.34814
# Min-max pre-processing average: 0.50403
# ======================================================
#
# C: 0.1, Degrees: 2, Gamma: 0.01
# No pre-processing, fold 1: 0.44781
# Standard pre-processing, fold 1: 0.58428
# Min-max pre-processing, fold 1: 0.53771
#
# No pre-processing, fold 2: 0.44469
# Standard pre-processing, fold 2: 0.57647
# Min-max pre-processing, fold 2: 0.48607
#
# No pre-processing, fold 3: 0.32566
# Standard pre-processing, fold 3: 0.57497
# Min-max pre-processing, fold 3: 0.46974
#
# No pre-processing, fold 4: 0.42921
# Standard pre-processing, fold 4: 0.60273
# Min-max pre-processing, fold 4: 0.50487
#
# ======================================================
# No pre-processing average: 0.41184
# Standard pre-processing average: 0.58461
# Min-max pre-processing average: 0.49960
# ======================================================
#
# C: 0.1, Degrees: 2, Gamma: 0.1
# No pre-processing, fold 1: 0.46046
# Standard pre-processing, fold 1: 0.83350
# Min-max pre-processing, fold 1: 0.65874
#
# No pre-processing, fold 2: 0.38240
# Standard pre-processing, fold 2: 0.85250
# Min-max pre-processing, fold 2: 0.66362
#
# No pre-processing, fold 3: 0.39376
# Standard pre-processing, fold 3: 0.85235
# Min-max pre-processing, fold 3: 0.66716
#
# No pre-processing, fold 4: 0.40223
# Standard pre-processing, fold 4: 0.83709
# Min-max pre-processing, fold 4: 0.70417
#
# ======================================================
# No pre-processing average: 0.40972
# Standard pre-processing average: 0.84386
# Min-max pre-processing average: 0.67342
# ======================================================
#
# C: 0.1, Degrees: 2, Gamma: 1
# No pre-processing, fold 1: 0.28319
# Standard pre-processing, fold 1: 0.80419
# Min-max pre-processing, fold 1: 0.83327
#
# No pre-processing, fold 2: 0.43329
# Standard pre-processing, fold 2: 0.80507
# Min-max pre-processing, fold 2: 0.85517
#
# No pre-processing, fold 3: 0.35466
# Standard pre-processing, fold 3: 0.80340
# Min-max pre-processing, fold 3: 0.84899
#
# No pre-processing, fold 4: 0.34151
# Standard pre-processing, fold 4: 0.79540
# Min-max pre-processing, fold 4: 0.84208
#
# ======================================================
# No pre-processing average: 0.35316
# Standard pre-processing average: 0.80201
# Min-max pre-processing average: 0.84488
# ======================================================
#
# C: 0.1, Degrees: 2, Gamma: 10
# No pre-processing, fold 1: 0.37023
# Standard pre-processing, fold 1: 0.74545
# Min-max pre-processing, fold 1: 0.74952
#
# No pre-processing, fold 2: 0.35294
# Standard pre-processing, fold 2: 0.77048
# Min-max pre-processing, fold 2: 0.77170
#
# No pre-processing, fold 3: 0.29753
# Standard pre-processing, fold 3: 0.77641
# Min-max pre-processing, fold 3: 0.75838
#
# No pre-processing, fold 4: 0.26369
# Standard pre-processing, fold 4: 0.77683
# Min-max pre-processing, fold 4: 0.72995
#
# ======================================================
# No pre-processing average: 0.32110
# Standard pre-processing average: 0.76730
# Min-max pre-processing average: 0.75239
# ======================================================
#
# C: 0.1, Degrees: 2, Gamma: 100
# No pre-processing, fold 1: 0.39743
# Standard pre-processing, fold 1: 0.73331
# Min-max pre-processing, fold 1: 0.65924
#
# No pre-processing, fold 2: 0.34971
# Standard pre-processing, fold 2: 0.76009
# Min-max pre-processing, fold 2: 0.68222
#
# No pre-processing, fold 3: 0.32250
# Standard pre-processing, fold 3: 0.77411
# Min-max pre-processing, fold 3: 0.65933
#
# No pre-processing, fold 4: 0.36500
# Standard pre-processing, fold 4: 0.76779
# Min-max pre-processing, fold 4: 0.65018
#
# ======================================================
# No pre-processing average: 0.35866
# Standard pre-processing average: 0.75882
# Min-max pre-processing average: 0.66274
# ======================================================
#
# C: 0.1, Degrees: 3, Gamma: 0.001
# No pre-processing, fold 1: 0.34122
# Standard pre-processing, fold 1: 0.22646
# Min-max pre-processing, fold 1: 0.46238
#
# No pre-processing, fold 2: 0.37031
# Standard pre-processing, fold 2: 0.29023
# Min-max pre-processing, fold 2: 0.44996
#
# No pre-processing, fold 3: 0.44416
# Standard pre-processing, fold 3: 0.24098
# Min-max pre-processing, fold 3: 0.47200
#
# No pre-processing, fold 4: 0.31011
# Standard pre-processing, fold 4: 0.24867
# Min-max pre-processing, fold 4: 0.45844
#
# ======================================================
# No pre-processing average: 0.36645
# Standard pre-processing average: 0.25159
# Min-max pre-processing average: 0.46069
# ======================================================
#
# C: 0.1, Degrees: 3, Gamma: 0.01
# No pre-processing, fold 1: 0.31791
# Standard pre-processing, fold 1: 0.35513
# Min-max pre-processing, fold 1: 0.46041
#
# No pre-processing, fold 2: 0.37032
# Standard pre-processing, fold 2: 0.37403
# Min-max pre-processing, fold 2: 0.45346
#
# No pre-processing, fold 3: 0.40947
# Standard pre-processing, fold 3: 0.34865
# Min-max pre-processing, fold 3: 0.47218
#
# No pre-processing, fold 4: 0.35042
# Standard pre-processing, fold 4: 0.36160
# Min-max pre-processing, fold 4: 0.45844
#
# ======================================================
# No pre-processing average: 0.36203
# Standard pre-processing average: 0.35985
# Min-max pre-processing average: 0.46112
# ======================================================
#
# C: 0.1, Degrees: 3, Gamma: 0.1
# No pre-processing, fold 1: 0.34558
# Standard pre-processing, fold 1: 0.84892
# Min-max pre-processing, fold 1: 0.65550
#
# No pre-processing, fold 2: 0.41489
# Standard pre-processing, fold 2: 0.87243
# Min-max pre-processing, fold 2: 0.67499
#
# No pre-processing, fold 3: 0.36791
# Standard pre-processing, fold 3: 0.86158
# Min-max pre-processing, fold 3: 0.69588
#
# No pre-processing, fold 4: 0.43988
# Standard pre-processing, fold 4: 0.85890
# Min-max pre-processing, fold 4: 0.71546
#
# ======================================================
# No pre-processing average: 0.39207
# Standard pre-processing average: 0.86046
# Min-max pre-processing average: 0.68546
# ======================================================
#
# C: 0.1, Degrees: 3, Gamma: 1
# No pre-processing, fold 1: 0.33856
# Standard pre-processing, fold 1: 0.76919
# Min-max pre-processing, fold 1: 0.83649
#
# No pre-processing, fold 2: 0.35480
# Standard pre-processing, fold 2: 0.78906
# Min-max pre-processing, fold 2: 0.87379
#
# No pre-processing, fold 3: 0.33784
# Standard pre-processing, fold 3: 0.76331
# Min-max pre-processing, fold 3: 0.86231
#
# No pre-processing, fold 4: 0.34829
# Standard pre-processing, fold 4: 0.78994
# Min-max pre-processing, fold 4: 0.86508
#
# ======================================================
# No pre-processing average: 0.34487
# Standard pre-processing average: 0.77787
# Min-max pre-processing average: 0.85942
# ======================================================
#
# C: 0.1, Degrees: 3, Gamma: 10
# No pre-processing, fold 1: 0.41903
# Standard pre-processing, fold 1: 0.77100
# Min-max pre-processing, fold 1: 0.70867
#
# No pre-processing, fold 2: 0.32132
# Standard pre-processing, fold 2: 0.78665
# Min-max pre-processing, fold 2: 0.72141
#
# No pre-processing, fold 3: 0.34975
# Standard pre-processing, fold 3: 0.77405
# Min-max pre-processing, fold 3: 0.71412
#
# No pre-processing, fold 4: 0.32698
# Standard pre-processing, fold 4: 0.78532
# Min-max pre-processing, fold 4: 0.73018
#
# ======================================================
# No pre-processing average: 0.35427
# Standard pre-processing average: 0.77925
# Min-max pre-processing average: 0.71860
# ======================================================
#
# C: 0.1, Degrees: 3, Gamma: 100
# No pre-processing, fold 1: 0.33100
# Standard pre-processing, fold 1: 0.77352
# Min-max pre-processing, fold 1: 0.72181
#
# No pre-processing, fold 2: 0.38502
# ...
#
# C: 100, Degrees: 1, Gamma: 0.1
# No pre-processing, fold 1: 0.36906
# Standard pre-processing, fold 1: 0.64262
# Min-max pre-processing, fold 1: 0.83782
#
# No pre-processing, fold 2: 0.32482
# Standard pre-processing, fold 2: 0.67781
# Min-max pre-processing, fold 2: 0.85894
#
# No pre-processing, fold 3: 0.43280
# Standard pre-processing, fold 3: 0.69237
# Min-max pre-processing, fold 3: 0.84702
#
# No pre-processing, fold 4: 0.45834
# Standard pre-processing, fold 4: 0.71329
# Min-max pre-processing, fold 4: 0.84633
#
# ======================================================
# No pre-processing average: 0.39626
# Standard pre-processing average: 0.68152
# Min-max pre-processing average: 0.84753
# ======================================================
#
# C: 100, Degrees: 1, Gamma: 1
# No pre-processing, fold 1: 0.43947
# Standard pre-processing, fold 1: 0.64184
# Min-max pre-processing, fold 1: 0.75887
#
# No pre-processing, fold 2: 0.31972
# Standard pre-processing, fold 2: 0.63850
# Min-max pre-processing, fold 2: 0.77579
#
# No pre-processing, fold 3: 0.35310
# Standard pre-processing, fold 3: 0.64090
# Min-max pre-processing, fold 3: 0.75941
#
# No pre-processing, fold 4: 0.41109
# Standard pre-processing, fold 4: 0.65700
# Min-max pre-processing, fold 4: 0.72020
#
# ======================================================
# No pre-processing average: 0.38085
# Standard pre-processing average: 0.64456
# Min-max pre-processing average: 0.75357
# ======================================================
#
# C: 100, Degrees: 1, Gamma: 10
# No pre-processing, fold 1: 0.38702
# Standard pre-processing, fold 1: 0.63398
# Min-max pre-processing, fold 1: 0.65232
#
# No pre-processing, fold 2: 0.29182
# Standard pre-processing, fold 2: 0.62131
# Min-max pre-processing, fold 2: 0.63242
#
# No pre-processing, fold 3: 0.45202
# Standard pre-processing, fold 3: 0.63230
# Min-max pre-processing, fold 3: 0.59069
#
# No pre-processing, fold 4: 0.36203
# Standard pre-processing, fold 4: 0.70522
# Min-max pre-processing, fold 4: 0.69195
#
# ======================================================
# No pre-processing average: 0.37322
# Standard pre-processing average: 0.64820
# Min-max pre-processing average: 0.64184
# ======================================================
#
# C: 100, Degrees: 1, Gamma: 100
# No pre-processing, fold 1: 0.39658
# Standard pre-processing, fold 1: 0.64844
# Min-max pre-processing, fold 1: 0.61952
#
# No pre-processing, fold 2: 0.42210
# Standard pre-processing, fold 2: 0.60208
# Min-max pre-processing, fold 2: 0.60409
#
# No pre-processing, fold 3: 0.38940
# Standard pre-processing, fold 3: 0.65632
# Min-max pre-processing, fold 3: 0.61265
#
# No pre-processing, fold 4: 0.41105
# Standard pre-processing, fold 4: 0.66376
# Min-max pre-processing, fold 4: 0.67151
#
# ======================================================
# No pre-processing average: 0.40478
# Standard pre-processing average: 0.64265
# Min-max pre-processing average: 0.62694
# ======================================================
#
# C: 100, Degrees: 2, Gamma: 0.001
# No pre-processing, fold 1: 0.43318
# Standard pre-processing, fold 1: 0.69249
# Min-max pre-processing, fold 1: 0.53936
#
# No pre-processing, fold 2: 0.37008
# Standard pre-processing, fold 2: 0.75605
# Min-max pre-processing, fold 2: 0.56886
#
# No pre-processing, fold 3: 0.31330
# Standard pre-processing, fold 3: 0.75176
# Min-max pre-processing, fold 3: 0.52742
#
# No pre-processing, fold 4: 0.47293
# Standard pre-processing, fold 4: 0.69473
# Min-max pre-processing, fold 4: 0.54976
#
# ======================================================
# No pre-processing average: 0.39737
# Standard pre-processing average: 0.72376
# Min-max pre-processing average: 0.54635
# ======================================================
#
# C: 100, Degrees: 2, Gamma: 0.01
# No pre-processing, fold 1: 0.44781
# Standard pre-processing, fold 1: 0.85430
# Min-max pre-processing, fold 1: 0.77798
#
# No pre-processing, fold 2: 0.44469
# Standard pre-processing, fold 2: 0.87778
# Min-max pre-processing, fold 2: 0.79875
#
# No pre-processing, fold 3: 0.32566
# Standard pre-processing, fold 3: 0.86889
# Min-max pre-processing, fold 3: 0.78833
#
# No pre-processing, fold 4: 0.42921
# Standard pre-processing, fold 4: 0.87173
# Min-max pre-processing, fold 4: 0.78357
#
# ======================================================
# No pre-processing average: 0.41184
# Standard pre-processing average: 0.86818
# Min-max pre-processing average: 0.78716
# ======================================================
#
# C: 100, Degrees: 2, Gamma: 0.1
# No pre-processing, fold 1: 0.46046
# Standard pre-processing, fold 1: 0.71076
# Min-max pre-processing, fold 1: 0.83778
#
# No pre-processing, fold 2: 0.38240
# Standard pre-processing, fold 2: 0.78039
# Min-max pre-processing, fold 2: 0.86885
#
# No pre-processing, fold 3: 0.39376
# Standard pre-processing, fold 3: 0.78385
# Min-max pre-processing, fold 3: 0.85091
#
# No pre-processing, fold 4: 0.40223
# Standard pre-processing, fold 4: 0.76956
# Min-max pre-processing, fold 4: 0.85932
#
# ======================================================
# No pre-processing average: 0.40972
# Standard pre-processing average: 0.76114
# Min-max pre-processing average: 0.85421
# ======================================================
#
# C: 100, Degrees: 2, Gamma: 1
# No pre-processing, fold 1: 0.28319
# Standard pre-processing, fold 1: 0.73164
# Min-max pre-processing, fold 1: 0.64758
#
# No pre-processing, fold 2: 0.43329
# Standard pre-processing, fold 2: 0.77584
# Min-max pre-processing, fold 2: 0.66655
#
# No pre-processing, fold 3: 0.35466
# Standard pre-processing, fold 3: 0.77647
# Min-max pre-processing, fold 3: 0.71483
#
# No pre-processing, fold 4: 0.34151
# Standard pre-processing, fold 4: 0.77116
# Min-max pre-processing, fold 4: 0.73002
#
# ======================================================
# No pre-processing average: 0.35316
# Standard pre-processing average: 0.76378
# Min-max pre-processing average: 0.68974
# ======================================================
#
# C: 100, Degrees: 2, Gamma: 10
# No pre-processing, fold 1: 0.37023
# Standard pre-processing, fold 1: 0.74545
# Min-max pre-processing, fold 1: 0.65356
#
# No pre-processing, fold 2: 0.35294
# Standard pre-processing, fold 2: 0.77048
# Min-max pre-processing, fold 2: 0.66629
#
# No pre-processing, fold 3: 0.29753
# Standard pre-processing, fold 3: 0.77641
# Min-max pre-processing, fold 3: 0.70730
#
# No pre-processing, fold 4: 0.26369
# Standard pre-processing, fold 4: 0.77683
# Min-max pre-processing, fold 4: 0.68037
#
# ======================================================
# No pre-processing average: 0.32110
# Standard pre-processing average: 0.76730
# Min-max pre-processing average: 0.67688
# ======================================================
#
# C: 100, Degrees: 2, Gamma: 100
# No pre-processing, fold 1: 0.39743
# Standard pre-processing, fold 1: 0.73183
# Min-max pre-processing, fold 1: 0.65924
#
# No pre-processing, fold 2: 0.34971
# Standard pre-processing, fold 2: 0.77316
# Min-max pre-processing, fold 2: 0.68222
#
# No pre-processing, fold 3: 0.32250
# Standard pre-processing, fold 3: 0.77760
# Min-max pre-processing, fold 3: 0.65933
#
# No pre-processing, fold 4: 0.36500
# Standard pre-processing, fold 4: 0.76779
# Min-max pre-processing, fold 4: 0.65747
#
# ======================================================
# No pre-processing average: 0.35866
# Standard pre-processing average: 0.76260
# Min-max pre-processing average: 0.66456
# ======================================================
#
# C: 100, Degrees: 3, Gamma: 0.001
# No pre-processing, fold 1: 0.34122
# Standard pre-processing, fold 1: 0.35513
# Min-max pre-processing, fold 1: 0.46041
#
# No pre-processing, fold 2: 0.37031
# Standard pre-processing, fold 2: 0.37403
# Min-max pre-processing, fold 2: 0.45346
#
# No pre-processing, fold 3: 0.44416
# Standard pre-processing, fold 3: 0.34865
# Min-max pre-processing, fold 3: 0.47218
#
# No pre-processing, fold 4: 0.31011
# Standard pre-processing, fold 4: 0.36160
# Min-max pre-processing, fold 4: 0.45844
#
# ======================================================
# No pre-processing average: 0.36645
# Standard pre-processing average: 0.35985
# Min-max pre-processing average: 0.46112
# ======================================================
#
# C: 100, Degrees: 3, Gamma: 0.01
# No pre-processing, fold 1: 0.31791
# Standard pre-processing, fold 1: 0.84946
# Min-max pre-processing, fold 1: 0.65550
#
# No pre-processing, fold 2: 0.37032
# Standard pre-processing, fold 2: 0.87240
# Min-max pre-processing, fold 2: 0.67499
#
# No pre-processing, fold 3: 0.40947
# Standard pre-processing, fold 3: 0.86203
# Min-max pre-processing, fold 3: 0.69588
#
# No pre-processing, fold 4: 0.35042
# Standard pre-processing, fold 4: 0.85892
# Min-max pre-processing, fold 4: 0.71546
#
# ======================================================
# No pre-processing average: 0.36203
# Standard pre-processing average: 0.86070
# Min-max pre-processing average: 0.68546
# ======================================================
#
# C: 100, Degrees: 3, Gamma: 0.1
# No pre-processing, fold 1: 0.34558
# Standard pre-processing, fold 1: 0.77560
# Min-max pre-processing, fold 1: 0.84001
#
# No pre-processing, fold 2: 0.41489
# Standard pre-processing, fold 2: 0.79332
# Min-max pre-processing, fold 2: 0.87547
#
# No pre-processing, fold 3: 0.36791
# Standard pre-processing, fold 3: 0.76494
# Min-max pre-processing, fold 3: 0.86253
#
# No pre-processing, fold 4: 0.43988
# Standard pre-processing, fold 4: 0.78067
# Min-max pre-processing, fold 4: 0.86371
#
# ======================================================
# No pre-processing average: 0.39207
# Standard pre-processing average: 0.77863
# Min-max pre-processing average: 0.86043
# ======================================================
#
# C: 100, Degrees: 3, Gamma: 1
# No pre-processing, fold 1: 0.33856
# Standard pre-processing, fold 1: 0.76919
# Min-max pre-processing, fold 1: 0.73291
#
# No pre-processing, fold 2: 0.35480
# Standard pre-processing, fold 2: 0.78906
# Min-max pre-processing, fold 2: 0.70233
#
# No pre-processing, fold 3: 0.33784
# Standard pre-processing, fold 3: 0.76331
# Min-max pre-processing, fold 3: 0.69609
#
# No pre-processing, fold 4: 0.34829
# Standard pre-processing, fold 4: 0.78994
# Min-max pre-processing, fold 4: 0.70172
#
# ======================================================
# No pre-processing average: 0.34487
# Standard pre-processing average: 0.77787
# Min-max pre-processing average: 0.70826
# ======================================================
#
# C: 100, Degrees: 3, Gamma: 10
# No pre-processing, fold 1: 0.41903
# Standard pre-processing, fold 1: 0.77155
# Min-max pre-processing, fold 1: 0.70867
#
# No pre-processing, fold 2: 0.32132
# Standard pre-processing, fold 2: 0.78665
# Min-max pre-processing, fold 2: 0.72141
#
# No pre-processing, fold 3: 0.34975
# Standard pre-processing, fold 3: 0.77362
# Min-max pre-processing, fold 3: 0.71412
#
# No pre-processing, fold 4: 0.32698
# Standard pre-processing, fold 4: 0.78532
# Min-max pre-processing, fold 4: 0.72776
#
# ======================================================
# No pre-processing average: 0.35427
# Standard pre-processing average: 0.77928
# Min-max pre-processing average: 0.71799
# ======================================================
#
# C: 100, Degrees: 3, Gamma: 100
# No pre-processing, fold 1: 0.33100
# Standard pre-processing, fold 1: 0.77352
# Min-max pre-processing, fold 1: 0.72181
#
# No pre-processing, fold 2: 0.38502
# Standard pre-processing, fold 2: 0.78135
# Min-max pre-processing, fold 2: 0.69790
#
# No pre-processing, fold 3: 0.40900
# Standard pre-processing, fold 3: 0.75973
# Min-max pre-processing, fold 3: 0.69411
#
# No pre-processing, fold 4: 0.37774
# Standard pre-processing, fold 4: 0.75914
# Min-max pre-processing, fold 4: 0.73865
#
# ======================================================
# No pre-processing average: 0.37569
# Standard pre-processing average: 0.76844
# Min-max pre-processing average: 0.71311
# ======================================================
#
# C: 100, Degrees: 4, Gamma: 0.001
# No pre-processing, fold 1: 0.38382
# Standard pre-processing, fold 1: 0.32818
# Min-max pre-processing, fold 1: 0.42449
#
# No pre-processing, fold 2: 0.33323
# Standard pre-processing, fold 2: 0.33452
# Min-max pre-processing, fold 2: 0.40892
#
# No pre-processing, fold 3: 0.29623
# Standard pre-processing, fold 3: 0.30492
# Min-max pre-processing, fold 3: 0.42525
#
# No pre-processing, fold 4: 0.26662
# Standard pre-processing, fold 4: 0.30597
# Min-max pre-processing, fold 4: 0.42447
#
# ======================================================
# No pre-processing average: 0.31998
# Standard pre-processing average: 0.31840
# Min-max pre-processing average: 0.42078
# ======================================================
#
# C: 100, Degrees: 4, Gamma: 0.01
# No pre-processing, fold 1: 0.39590
# Standard pre-processing, fold 1: 0.78884
# Min-max pre-processing, fold 1: 0.50712
#
# No pre-processing, fold 2: 0.40526
# Standard pre-processing, fold 2: 0.80956
# Min-max pre-processing, fold 2: 0.53112
#
# No pre-processing, fold 3: 0.25164
# Standard pre-processing, fold 3: 0.80954
# Min-max pre-processing, fold 3: 0.48071
#
# No pre-processing, fold 4: 0.34011
# Standard pre-processing, fold 4: 0.79309
# Min-max pre-processing, fold 4: 0.50918
#
# ======================================================
# No pre-processing average: 0.34823
# Standard pre-processing average: 0.80026
# Min-max pre-processing average: 0.50703
# ======================================================
#
# C: 100, Degrees: 4, Gamma: 0.1
# No pre-processing, fold 1: 0.44982
# Standard pre-processing, fold 1: 0.76132
# Min-max pre-processing, fold 1: 0.85412
#
# No pre-processing, fold 2: 0.30051
# Standard pre-processing, fold 2: 0.81886
# Min-max pre-processing, fold 2: 0.86259
#
# No pre-processing, fold 3: 0.28945
# Standard pre-processing, fold 3: 0.80355
# Min-max pre-processing, fold 3: 0.86252
#
# No pre-processing, fold 4: 0.34979
# Standard pre-processing, fold 4: 0.74699
# Min-max pre-processing, fold 4: 0.85885
#
# ======================================================
# No pre-processing average: 0.34739
# Standard pre-processing average: 0.78268
# Min-max pre-processing average: 0.85952
# ======================================================
#
# C: 100, Degrees: 4, Gamma: 1
# No pre-processing, fold 1: 0.33104
# Standard pre-processing, fold 1: 0.75097
# Min-max pre-processing, fold 1: 0.72200
#
# No pre-processing, fold 2: 0.40986
# Standard pre-processing, fold 2: 0.81787
# Min-max pre-processing, fold 2: 0.72395
#
# No pre-processing, fold 3: 0.31360
# Standard pre-processing, fold 3: 0.77019
# Min-max pre-processing, fold 3: 0.71323
#
# No pre-processing, fold 4: 0.34438
# Standard pre-processing, fold 4: 0.77828
# Min-max pre-processing, fold 4: 0.71013
#
# ======================================================
# No pre-processing average: 0.34972
# Standard pre-processing average: 0.77933
# Min-max pre-processing average: 0.71733
# ======================================================
#
# C: 100, Degrees: 4, Gamma: 10
# No pre-processing, fold 1: 0.33595
# Standard pre-processing, fold 1: 0.74968
# Min-max pre-processing, fold 1: 0.73074
#
# No pre-processing, fold 2: 0.39381
# Standard pre-processing, fold 2: 0.80115
# Min-max pre-processing, fold 2: 0.74755
#
# No pre-processing, fold 3: 0.35419
# Standard pre-processing, fold 3: 0.78778
# Min-max pre-processing, fold 3: 0.71111
#
# No pre-processing, fold 4: 0.26560
# Standard pre-processing, fold 4: 0.75439
# Min-max pre-processing, fold 4: 0.72801
#
# ======================================================
# No pre-processing average: 0.33739
# Standard pre-processing average: 0.77325
# Min-max pre-processing average: 0.72935
# ======================================================
#
# C: 100, Degrees: 4, Gamma: 100
# No pre-processing, fold 1: 0.14722
# Standard pre-processing, fold 1: 0.74958
# Min-max pre-processing, fold 1: 0.71037
#
# No pre-processing, fold 2: 0.21724
# Standard pre-processing, fold 2: 0.81613
# Min-max pre-processing, fold 2: 0.74324
# No pre-processing, fold 3: 0.16748
# Standard pre-processing, fold 3: 0.72089
# Min-max pre-processing, fold 3: 0.70961
#
# No pre-processing, fold 4: 0.16940
# Standard pre-processing, fold 4: 0.73807
# Min-max pre-processing, fold 4: 0.70851
#
# ======================================================
# No pre-processing average: 0.17534
# Standard pre-processing average: 0.75617
# Min-max pre-processing average: 0.71793
# ======================================================

# %%
# sklearn neural network
from sklearn.neural_network import MLPClassifier

hidden_layers = [(20), (100), (20, 20), (100, 100)]
alpha_values = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]

for hl in hidden_layers:
    for alpha in alpha_values:
        clf = MLPClassifier(alpha=alpha, hidden_layer_sizes=hl, random_state=seed)
        print("Hidden layers: {}. Alpha value: {}".format(hl, alpha))
        cross_val(X, y, clf, skf)
        print()
# Out:
# Hidden layers: 20. Alpha value: 0.0001
# No pre-processing, fold 1: 0.70059
# Standard pre-processing, fold 1: 0.85374
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Min-max pre-processing, fold 1: 0.81250
#
# No pre-processing, fold 2: 0.67384
# Standard pre-processing, fold 2: 0.86672
# Min-max pre-processing, fold 2: 0.82909
#
# No pre-processing, fold 3: 0.61731
# Standard pre-processing, fold 3: 0.85348
# Min-max pre-processing, fold 3: 0.83060
#
# No pre-processing, fold 4: 0.68155
# Standard pre-processing, fold 4: 0.86501
# Min-max pre-processing, fold 4: 0.81998
#
# ======================================================
# No pre-processing average: 0.66832
# Standard pre-processing average: 0.85974
# Min-max pre-processing average: 0.82304
# ======================================================
#
# Hidden layers: 20. Alpha value: 0.001
# No pre-processing, fold 1: 0.69365
# Standard pre-processing, fold 1: 0.85371
# Min-max pre-processing, fold 1: 0.81744
#
# No pre-processing, fold 2: 0.57693
# Standard pre-processing, fold 2: 0.86718
# Min-max pre-processing, fold 2: 0.83798
#
# No pre-processing, fold 3: 0.61661
# Standard pre-processing, fold 3: 0.85388
# Min-max pre-processing, fold 3: 0.83333
#
# No pre-processing, fold 4: 0.68971
# Standard pre-processing, fold 4: 0.86469
# Min-max pre-processing, fold 4: 0.81843
#
# ======================================================
# No pre-processing average: 0.64423
# Standard pre-processing average: 0.85987
# Min-max pre-processing average: 0.82679
# ======================================================
#
# Hidden layers: 20. Alpha value: 0.01
# No pre-processing, fold 1: 0.63796
# Standard pre-processing, fold 1: 0.85241
# Min-max pre-processing, fold 1: 0.82008
#
# No pre-processing, fold 2: 0.57610
# Standard pre-processing, fold 2: 0.86745
# Min-max pre-processing, fold 2: 0.83906
#
# No pre-processing, fold 3: 0.60847
# Standard pre-processing, fold 3: 0.85484
# Min-max pre-processing, fold 3: 0.83337
#
# No pre-processing, fold 4: 0.61968
# Standard pre-processing, fold 4: 0.86345
# Min-max pre-processing, fold 4: 0.82735
#
# ======================================================
# No pre-processing average: 0.61055
# Standard pre-processing average: 0.85954
# Min-max pre-processing average: 0.82996
# ======================================================
#
# Hidden layers: 20. Alpha value: 0.1
# No pre-processing, fold 1: 0.66338
# Standard pre-processing, fold 1: 0.85248
# Min-max pre-processing, fold 1: 0.80284
#
# No pre-processing, fold 2: 0.67275
# Standard pre-processing, fold 2: 0.86407
# Min-max pre-processing, fold 2: 0.83708
#
# No pre-processing, fold 3: 0.60719
# Standard pre-processing, fold 3: 0.85200
# Min-max pre-processing, fold 3: 0.83088
#
# No pre-processing, fold 4: 0.68700
# Standard pre-processing, fold 4: 0.86315
# Min-max pre-processing, fold 4: 0.82160
#
# ======================================================
# No pre-processing average: 0.65758
# Standard pre-processing average: 0.85793
# Min-max pre-processing average: 0.82310
# ======================================================
#
# Hidden layers: 20. Alpha value: 1
# No pre-processing, fold 1: 0.64576
# Standard pre-processing, fold 1: 0.83538
# Min-max pre-processing, fold 1: 0.75621
#
# No pre-processing, fold 2: 0.67700
# Standard pre-processing, fold 2: 0.84521
# Min-max pre-processing, fold 2: 0.77058
#
# No pre-processing, fold 3: 0.65131
# Standard pre-processing, fold 3: 0.83994
# Min-max pre-processing, fold 3: 0.76405
#
# No pre-processing, fold 4: 0.66911
# Standard pre-processing, fold 4: 0.84085
# Min-max pre-processing, fold 4: 0.76272
#
# ======================================================
# No pre-processing average: 0.66079
# Standard pre-processing average: 0.84034
# Min-max pre-processing average: 0.76339
# ======================================================
#
# Hidden layers: 20. Alpha value: 10
# No pre-processing, fold 1: 0.62552
# Standard pre-processing, fold 1: 0.73742
# Min-max pre-processing, fold 1: 0.50857
#
# No pre-processing, fold 2: 0.69327
# Standard pre-processing, fold 2: 0.76455
# Min-max pre-processing, fold 2: 0.50915
#
# No pre-processing, fold 3: 0.65375
# Standard pre-processing, fold 3: 0.74530
# Min-max pre-processing, fold 3: 0.55477
#
# No pre-processing, fold 4: 0.63928
# Standard pre-processing, fold 4: 0.74712
# Min-max pre-processing, fold 4: 0.52278
#
# ======================================================
# No pre-processing average: 0.65296
# Standard pre-processing average: 0.74860
# Min-max pre-processing average: 0.52382
# ======================================================
#
# Hidden layers: 20. Alpha value: 100
# No pre-processing, fold 1: 0.61745
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Standard pre-processing, fold 1: 0.33344
# Min-max pre-processing, fold 1: 0.02222
#
# No pre-processing, fold 2: 0.64540
# Standard pre-processing, fold 2: 0.34015
# Min-max pre-processing, fold 2: 0.02222
#
# No pre-processing, fold 3: 0.51046
# Standard pre-processing, fold 3: 0.33394
# Min-max pre-processing, fold 3: 0.02222
#
# No pre-processing, fold 4: 0.64214
# Standard pre-processing, fold 4: 0.34815
# Min-max pre-processing, fold 4: 0.02222
#
# ======================================================
# No pre-processing average: 0.60386
# Standard pre-processing average: 0.33892
# Min-max pre-processing average: 0.02222
# ======================================================
#
# Hidden layers: 100. Alpha value: 0.0001
# No pre-processing, fold 1: 0.67230
# Standard pre-processing, fold 1: 0.87557
# Min-max pre-processing, fold 1: 0.82020
#
# No pre-processing, fold 2: 0.61063
# Standard pre-processing, fold 2: 0.88456
# Min-max pre-processing, fold 2: 0.84061
#
# No pre-processing, fold 3: 0.64280
# Standard pre-processing, fold 3: 0.87684
# Min-max pre-processing, fold 3: 0.84626
#
# No pre-processing, fold 4: 0.58590
# Standard pre-processing, fold 4: 0.87424
# Min-max pre-processing, fold 4: 0.83431
#
# ======================================================
# No pre-processing average: 0.62791
# Standard pre-processing average: 0.87780
# Min-max pre-processing average: 0.83534
# ======================================================
#
# Hidden layers: 100. Alpha value: 0.001
# No pre-processing, fold 1: 0.64076
# Standard pre-processing, fold 1: 0.87420
# Min-max pre-processing, fold 1: 0.82201
#
# No pre-processing, fold 2: 0.63607
# Standard pre-processing, fold 2: 0.88481
# Min-max pre-processing, fold 2: 0.83858
#
# No pre-processing, fold 3: 0.58349
# Standard pre-processing, fold 3: 0.87925
# Min-max pre-processing, fold 3: 0.84650
#
# No pre-processing, fold 4: 0.64152
# Standard pre-processing, fold 4: 0.87192
# Min-max pre-processing, fold 4: 0.83642
#
# ======================================================
# No pre-processing average: 0.62546
# Standard pre-processing average: 0.87754
# Min-max pre-processing average: 0.83587
# ======================================================
#
# Hidden layers: 100. Alpha value: 0.01
# No pre-processing, fold 1: 0.73868
# Standard pre-processing, fold 1: 0.87641
# Min-max pre-processing, fold 1: 0.82317
#
# No pre-processing, fold 2: 0.67983
# Standard pre-processing, fold 2: 0.88050
# Min-max pre-processing, fold 2: 0.84084
#
# No pre-processing, fold 3: 0.71003
# Standard pre-processing, fold 3: 0.87887
# Min-max pre-processing, fold 3: 0.84761
#
# No pre-processing, fold 4: 0.70188
# Standard pre-processing, fold 4: 0.87172
# Min-max pre-processing, fold 4: 0.83370
#
# ======================================================
# No pre-processing average: 0.70761
# Standard pre-processing average: 0.87687
# Min-max pre-processing average: 0.83633
# ======================================================
#
# Hidden layers: 100. Alpha value: 0.1
# No pre-processing, fold 1: 0.60393
# Standard pre-processing, fold 1: 0.87770
# Min-max pre-processing, fold 1: 0.81208
#
# No pre-processing, fold 2: 0.69445
# Standard pre-processing, fold 2: 0.88193
# Min-max pre-processing, fold 2: 0.83208
#
# No pre-processing, fold 3: 0.69107
# Standard pre-processing, fold 3: 0.87594
# Min-max pre-processing, fold 3: 0.83556
#
# No pre-processing, fold 4: 0.63467
# Standard pre-processing, fold 4: 0.86859
# Min-max pre-processing, fold 4: 0.82338
#
# ======================================================
# No pre-processing average: 0.65603
# Standard pre-processing average: 0.87604
# Min-max pre-processing average: 0.82578
# ======================================================
#
# Hidden layers: 100. Alpha value: 1
# No pre-processing, fold 1: 0.64061
# Standard pre-processing, fold 1: 0.84398
# Min-max pre-processing, fold 1: 0.74318
#
# No pre-processing, fold 2: 0.65454
# Standard pre-processing, fold 2: 0.85800
# Min-max pre-processing, fold 2: 0.76953
#
# No pre-processing, fold 3: 0.66940
# Standard pre-processing, fold 3: 0.85377
# Min-max pre-processing, fold 3: 0.76216
#
# No pre-processing, fold 4: 0.65177
# Standard pre-processing, fold 4: 0.84693
# Min-max pre-processing, fold 4: 0.75819
#
# ======================================================
# No pre-processing average: 0.65408
# Standard pre-processing average: 0.85067
# Min-max pre-processing average: 0.75826
# ======================================================
#
# Hidden layers: 100. Alpha value: 10
# No pre-processing, fold 1: 0.67820
# Standard pre-processing, fold 1: 0.72743
# Min-max pre-processing, fold 1: 0.45889
#
# No pre-processing, fold 2: 0.72632
# Standard pre-processing, fold 2: 0.75645
# Min-max pre-processing, fold 2: 0.56879
#
# No pre-processing, fold 3: 0.64834
# Standard pre-processing, fold 3: 0.74046
# Min-max pre-processing, fold 3: 0.56798
#
# No pre-processing, fold 4: 0.68128
# Standard pre-processing, fold 4: 0.73359
# Min-max pre-processing, fold 4: 0.55884
#
# ======================================================
# No pre-processing average: 0.68354
# Standard pre-processing average: 0.73948
# Min-max pre-processing average: 0.53863
# ======================================================
#
# Hidden layers: 100. Alpha value: 100
# No pre-processing, fold 1: 0.68299
# Standard pre-processing, fold 1: 0.31221
# Min-max pre-processing, fold 1: 0.02222
#
# No pre-processing, fold 2: 0.59358
# Standard pre-processing, fold 2: 0.35481
# Min-max pre-processing, fold 2: 0.02222
#
# No pre-processing, fold 3: 0.57961
# Standard pre-processing, fold 3: 0.31654
# Min-max pre-processing, fold 3: 0.02222
#
# No pre-processing, fold 4: 0.65101
# Standard pre-processing, fold 4: 0.33867
# Min-max pre-processing, fold 4: 0.02222
#
# ======================================================
# No pre-processing average: 0.62680
# Standard pre-processing average: 0.33056
# Min-max pre-processing average: 0.02222
# ======================================================
#
# Hidden layers: (20, 20). Alpha value: 0.0001
# No pre-processing, fold 1: 0.62966
# Standard pre-processing, fold 1: 0.85397
# Min-max pre-processing, fold 1: 0.80774
#
# No pre-processing, fold 2: 0.65625
# Standard pre-processing, fold 2: 0.86905
# Min-max pre-processing, fold 2: 0.80900
#
# No pre-processing, fold 3: 0.61383
# Standard pre-processing, fold 3: 0.85764
# Min-max pre-processing, fold 3: 0.82304
#
# No pre-processing, fold 4: 0.63262
# Standard pre-processing, fold 4: 0.85437
# Min-max pre-processing, fold 4: 0.81518
#
# ======================================================
# No pre-processing average: 0.63309
# Standard pre-processing average: 0.85875
# Min-max pre-processing average: 0.81374
# ======================================================
#
# Hidden layers: (20, 20). Alpha value: 0.001
# No pre-processing, fold 1: 0.65889
# Standard pre-processing, fold 1: 0.85248
# Min-max pre-processing, fold 1: 0.80889
#
# No pre-processing, fold 2: 0.67455
# Standard pre-processing, fold 2: 0.86097
# Min-max pre-processing, fold 2: 0.81414
#
# No pre-processing, fold 3: 0.61515
# Standard pre-processing, fold 3: 0.86356
# Min-max pre-processing, fold 3: 0.82200
#
# No pre-processing, fold 4: 0.66474
# Standard pre-processing, fold 4: 0.85069
# Min-max pre-processing, fold 4: 0.81147
#
# ======================================================
# No pre-processing average: 0.65333
# Standard pre-processing average: 0.85693
# Min-max pre-processing average: 0.81412
# ======================================================
#
# Hidden layers: (20, 20). Alpha value: 0.01
# No pre-processing, fold 1: 0.60300
# Standard pre-processing, fold 1: 0.85347
# Min-max pre-processing, fold 1: 0.80772
#
# No pre-processing, fold 2: 0.63249
# Standard pre-processing, fold 2: 0.86682
# Min-max pre-processing, fold 2: 0.81595
#
# No pre-processing, fold 3: 0.63651
# Standard pre-processing, fold 3: 0.86013
# Min-max pre-processing, fold 3: 0.82049
#
# No pre-processing, fold 4: 0.67692
# Standard pre-processing, fold 4: 0.85588
# Min-max pre-processing, fold 4: 0.81155
#
# ======================================================
# No pre-processing average: 0.63723
# Standard pre-processing average: 0.85907
# Min-max pre-processing average: 0.81393
# ======================================================
#
# Hidden layers: (20, 20). Alpha value: 0.1
# No pre-processing, fold 1: 0.67012
# Standard pre-processing, fold 1: 0.85207
# Min-max pre-processing, fold 1: 0.81501
#
# No pre-processing, fold 2: 0.66346
# Standard pre-processing, fold 2: 0.86668
# Min-max pre-processing, fold 2: 0.81390
#
# No pre-processing, fold 3: 0.60357
# Standard pre-processing, fold 3: 0.86310
# Min-max pre-processing, fold 3: 0.81777
#
# No pre-processing, fold 4: 0.63652
# Standard pre-processing, fold 4: 0.85583
# Min-max pre-processing, fold 4: 0.81465
#
# ======================================================
# No pre-processing average: 0.64342
# Standard pre-processing average: 0.85942
# Min-max pre-processing average: 0.81533
# ======================================================
#
# Hidden layers: (20, 20). Alpha value: 1
# No pre-processing, fold 1: 0.57110
# Standard pre-processing, fold 1: 0.84531
# Min-max pre-processing, fold 1: 0.77297
#
# No pre-processing, fold 2: 0.61774
# Standard pre-processing, fold 2: 0.85269
# Min-max pre-processing, fold 2: 0.78214
#
# No pre-processing, fold 3: 0.60437
# Standard pre-processing, fold 3: 0.85587
# Min-max pre-processing, fold 3: 0.78316
#
# No pre-processing, fold 4: 0.57526
# Standard pre-processing, fold 4: 0.84807
# Min-max pre-processing, fold 4: 0.78423
#
# ======================================================
# No pre-processing average: 0.59212
# Standard pre-processing average: 0.85048
# Min-max pre-processing average: 0.78062
# ======================================================
#
# Hidden layers: (20, 20). Alpha value: 10
# No pre-processing, fold 1: 0.66433
# Standard pre-processing, fold 1: 0.73174
# Min-max pre-processing, fold 1: 0.53003
#
# No pre-processing, fold 2: 0.68337
# Standard pre-processing, fold 2: 0.74537
# Min-max pre-processing, fold 2: 0.56391
#
# No pre-processing, fold 3: 0.69879
# Standard pre-processing, fold 3: 0.74161
# Min-max pre-processing, fold 3: 0.56294
#
# No pre-processing, fold 4: 0.66494
# Standard pre-processing, fold 4: 0.74088
# Min-max pre-processing, fold 4: 0.55984
#
# ======================================================
# No pre-processing average: 0.67786
# Standard pre-processing average: 0.73990
# Min-max pre-processing average: 0.55418
# ======================================================
#
# Hidden layers: (20, 20). Alpha value: 100
# No pre-processing, fold 1: 0.60139
# Standard pre-processing, fold 1: 0.02222
# Min-max pre-processing, fold 1: 0.02222
#
# No pre-processing, fold 2: 0.60975
# Standard pre-processing, fold 2: 0.02222
# Min-max pre-processing, fold 2: 0.02222
#
# No pre-processing, fold 3: 0.60335
# Standard pre-processing, fold 3: 0.02222
# Min-max pre-processing, fold 3: 0.02222
#
# No pre-processing, fold 4: 0.56369
# Standard pre-processing, fold 4: 0.02222
# Min-max pre-processing, fold 4: 0.02222
#
# ======================================================
# No pre-processing average: 0.59455
# Standard pre-processing average: 0.02222
# Min-max pre-processing average: 0.02222
# ======================================================
#
# Hidden layers: (100, 100). Alpha value: 0.0001
# No pre-processing, fold 1: 0.63573
# Standard pre-processing, fold 1: 0.86863
# Min-max pre-processing, fold 1: 0.83835
#
# No pre-processing, fold 2: 0.60714
# Standard pre-processing, fold 2: 0.89381
# Min-max pre-processing, fold 2: 0.86180
#
# No pre-processing, fold 3: 0.53277
# Standard pre-processing, fold 3: 0.87898
# Min-max pre-processing, fold 3: 0.84403
#
# No pre-processing, fold 4: 0.53082
# Standard pre-processing, fold 4: 0.87821
# Min-max pre-processing, fold 4: 0.83169
#
# ======================================================
# No pre-processing average: 0.57661
# Standard pre-processing average: 0.87991
# Min-max pre-processing average: 0.84397
# ======================================================
#
# Hidden layers: (100, 100). Alpha value: 0.001
# No pre-processing, fold 1: 0.58588
# Standard pre-processing, fold 1: 0.87322
# Min-max pre-processing, fold 1: 0.83850
#
# No pre-processing, fold 2: 0.66939
# Standard pre-processing, fold 2: 0.89031
# Min-max pre-processing, fold 2: 0.84569
#
# No pre-processing, fold 3: 0.50959
# Standard pre-processing, fold 3: 0.87939
# Min-max pre-processing, fold 3: 0.84932
#
# No pre-processing, fold 4: 0.49018
# Standard pre-processing, fold 4: 0.87660
# Min-max pre-processing, fold 4: 0.83593
#
# ======================================================
# No pre-processing average: 0.56376
# Standard pre-processing average: 0.87988
# Min-max pre-processing average: 0.84236
# ======================================================
#
# Hidden layers: (100, 100). Alpha value: 0.01
# No pre-processing, fold 1: 0.59002
# Standard pre-processing, fold 1: 0.87340
# Min-max pre-processing, fold 1: 0.82864
#
# No pre-processing, fold 2: 0.56967
# Standard pre-processing, fold 2: 0.89252
# Min-max pre-processing, fold 2: 0.86201
#
# No pre-processing, fold 3: 0.58518
# Standard pre-processing, fold 3: 0.87497
# Min-max pre-processing, fold 3: 0.85041
#
# No pre-processing, fold 4: 0.64394
# Standard pre-processing, fold 4: 0.87876
# Min-max pre-processing, fold 4: 0.83239
#
# ======================================================
# No pre-processing average: 0.59720
# Standard pre-processing average: 0.87991
# Min-max pre-processing average: 0.84336
# ======================================================
#
# Hidden layers: (100, 100). Alpha value: 0.1
# No pre-processing, fold 1: 0.49180
# Standard pre-processing, fold 1: 0.85056
# Min-max pre-processing, fold 1: 0.82638
#
# No pre-processing, fold 2: 0.52955
# Standard pre-processing, fold 2: 0.87740
# Min-max pre-processing, fold 2: 0.82028
#
# No pre-processing, fold 3: 0.53785
# Standard pre-processing, fold 3: 0.88320
# Min-max pre-processing, fold 3: 0.84754
#
# No pre-processing, fold 4: 0.45875
# Standard pre-processing, fold 4: 0.87929
# Min-max pre-processing, fold 4: 0.83106
#
# ======================================================
# No pre-processing average: 0.50449
# Standard pre-processing average: 0.87261
# Min-max pre-processing average: 0.83132
# ======================================================
#
# Hidden layers: (100, 100). Alpha value: 1
# No pre-processing, fold 1: 0.56989
# Standard pre-processing, fold 1: 0.85031
# Min-max pre-processing, fold 1: 0.78526
#
# No pre-processing, fold 2: 0.45466
# Standard pre-processing, fold 2: 0.87024
# Min-max pre-processing, fold 2: 0.79099
#
# No pre-processing, fold 3: 0.67614
# Standard pre-processing, fold 3: 0.87287
# Min-max pre-processing, fold 3: 0.80076
#
# No pre-processing, fold 4: 0.55999
# Standard pre-processing, fold 4: 0.85307
# Min-max pre-processing, fold 4: 0.78963
#
# ======================================================
# No pre-processing average: 0.56517
# Standard pre-processing average: 0.86162
# Min-max pre-processing average: 0.79166
# ======================================================
#
# Hidden layers: (100, 100). Alpha value: 10
# No pre-processing, fold 1: 0.62305
# Standard pre-processing, fold 1: 0.72015
# Min-max pre-processing, fold 1: 0.54176
#
# No pre-processing, fold 2: 0.64954
# Standard pre-processing, fold 2: 0.75898
# Min-max pre-processing, fold 2: 0.54617
#
# No pre-processing, fold 3: 0.60235
# Standard pre-processing, fold 3: 0.71735
# Min-max pre-processing, fold 3: 0.54884
#
# No pre-processing, fold 4: 0.64103
# Standard pre-processing, fold 4: 0.73066
# Min-max pre-processing, fold 4: 0.54316
#
# ======================================================
# No pre-processing average: 0.62899
# Standard pre-processing average: 0.73178
# Min-max pre-processing average: 0.54498
# ======================================================
#
# Hidden layers: (100, 100). Alpha value: 100
# No pre-processing, fold 1: 0.55620
# Standard pre-processing, fold 1: 0.02222
# Min-max pre-processing, fold 1: 0.02222
#
# No pre-processing, fold 2: 0.64605
# Standard pre-processing, fold 2: 0.02222
# Min-max pre-processing, fold 2: 0.02222
#
# No pre-processing, fold 3: 0.46341
# Standard pre-processing, fold 3: 0.02222
# Min-max pre-processing, fold 3: 0.02222
#
# No pre-processing, fold 4: 0.52172
# Standard pre-processing, fold 4: 0.02222
# Min-max pre-processing, fold 4: 0.02222
#
# ======================================================
# No pre-processing average: 0.54685
# Standard pre-processing average: 0.02222
# Min-max pre-processing average: 0.02222
# ======================================================

# %%
# sklearn neural network
from sklearn.neural_network import MLPClassifier

hidden_layers = [(30), (200), (30, 30), (200, 200)]
alpha_values = [0.0001, 0.001, 0.01, 0.1, 1, 10]

for hl in hidden_layers:
    for alpha in alpha_values:
        clf = MLPClassifier(alpha=alpha, hidden_layer_sizes=hl, random_state=seed)
        print("Hidden layers: {}. Alpha value: {}".format(hl, alpha))
        cross_val(X, y, clf, skf)
        print()
# Out:
# Hidden layers: 30. Alpha value: 0.0001
# No pre-processing, fold 1: 0.68279
# Standard pre-processing, fold 1: 0.85978
# Min-max pre-processing, fold 1: 0.81971
#
# No pre-processing, fold 2: 0.68810
# Standard pre-processing, fold 2: 0.87202
# Min-max pre-processing, fold 2: 0.83397
#
# No pre-processing, fold 3: 0.72283
# Standard pre-processing, fold 3: 0.86767
# Min-max pre-processing, fold 3: 0.83869
#
# No pre-processing, fold 4: 0.71348
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Standard pre-processing, fold 4: 0.87029
# Min-max pre-processing, fold 4: 0.82881
#
# ======================================================
# No pre-processing average: 0.70180
# Standard pre-processing average: 0.86744
# Min-max pre-processing average: 0.83030
# ======================================================
#
# Hidden layers: 30. Alpha value: 0.001
# No pre-processing, fold 1: 0.67243
# Standard pre-processing, fold 1: 0.85892
# Min-max pre-processing, fold 1: 0.82787
#
# No pre-processing, fold 2: 0.68188
# Standard pre-processing, fold 2: 0.87224
# Min-max pre-processing, fold 2: 0.82739
#
# No pre-processing, fold 3: 0.67319
# Standard pre-processing, fold 3: 0.87236
# Min-max pre-processing, fold 3: 0.83273
#
# No pre-processing, fold 4: 0.71946
# Standard pre-processing, fold 4: 0.86661
# Min-max pre-processing, fold 4: 0.82940
#
# ======================================================
# No pre-processing average: 0.68674
# Standard pre-processing average: 0.86753
# Min-max pre-processing average: 0.82935
# ======================================================
#
# Hidden layers: 30. Alpha value: 0.01
# No pre-processing, fold 1: 0.66367
# Standard pre-processing, fold 1: 0.85892
# Min-max pre-processing, fold 1: 0.80745
#
# No pre-processing, fold 2: 0.68115
# Standard pre-processing, fold 2: 0.87237
# Min-max pre-processing, fold 2: 0.83300
#
# No pre-processing, fold 3: 0.67470
# Standard pre-processing, fold 3: 0.86759
# Min-max pre-processing, fold 3: 0.84074
#
# No pre-processing, fold 4: 0.71797
# Standard pre-processing, fold 4: 0.86479
# Min-max pre-processing, fold 4: 0.83079
#
# ======================================================
# No pre-processing average: 0.68437
# Standard pre-processing average: 0.86592
# Min-max pre-processing average: 0.82799
# ======================================================
#
# Hidden layers: 30. Alpha value: 0.1
# No pre-processing, fold 1: 0.63792
# Standard pre-processing, fold 1: 0.86319
# Min-max pre-processing, fold 1: 0.81495
#
# No pre-processing, fold 2: 0.71688
# Standard pre-processing, fold 2: 0.87124
# Min-max pre-processing, fold 2: 0.82012
#
# No pre-processing, fold 3: 0.68412
# Standard pre-processing, fold 3: 0.86492
# Min-max pre-processing, fold 3: 0.84285
#
# No pre-processing, fold 4: 0.66503
# Standard pre-processing, fold 4: 0.85765
# Min-max pre-processing, fold 4: 0.81674
#
# ======================================================
# No pre-processing average: 0.67599
# Standard pre-processing average: 0.86425
# Min-max pre-processing average: 0.82366
# ======================================================
#
# Hidden layers: 30. Alpha value: 1
# No pre-processing, fold 1: 0.63335
# Standard pre-processing, fold 1: 0.84242
# Min-max pre-processing, fold 1: 0.75014
#
# No pre-processing, fold 2: 0.69911
# Standard pre-processing, fold 2: 0.84900
# Min-max pre-processing, fold 2: 0.77797
#
# No pre-processing, fold 3: 0.71893
# Standard pre-processing, fold 3: 0.84584
# Min-max pre-processing, fold 3: 0.76298
#
# No pre-processing, fold 4: 0.60284
# Standard pre-processing, fold 4: 0.84392
# Min-max pre-processing, fold 4: 0.75673
#
# ======================================================
# No pre-processing average: 0.66356
# Standard pre-processing average: 0.84529
# Min-max pre-processing average: 0.76195
# ======================================================
#
# Hidden layers: 30. Alpha value: 10
# No pre-processing, fold 1: 0.68405
# Standard pre-processing, fold 1: 0.73769
# Min-max pre-processing, fold 1: 0.50080
#
# No pre-processing, fold 2: 0.74684
# Standard pre-processing, fold 2: 0.76596
# Min-max pre-processing, fold 2: 0.50095
#
# No pre-processing, fold 3: 0.68527
# Standard pre-processing, fold 3: 0.74947
# Min-max pre-processing, fold 3: 0.54137
#
# No pre-processing, fold 4: 0.66268
# Standard pre-processing, fold 4: 0.74596
# Min-max pre-processing, fold 4: 0.52790
#
# ======================================================
# No pre-processing average: 0.69471
# Standard pre-processing average: 0.74977
# Min-max pre-processing average: 0.51776
# ======================================================
#
# Hidden layers: 200. Alpha value: 0.0001
# No pre-processing, fold 1: 0.57210
# Standard pre-processing, fold 1: 0.87600
# Min-max pre-processing, fold 1: 0.83462
#
# No pre-processing, fold 2: 0.65955
# Standard pre-processing, fold 2: 0.88878
# Min-max pre-processing, fold 2: 0.84457
#
# No pre-processing, fold 3: 0.65267
# Standard pre-processing, fold 3: 0.88070
# Min-max pre-processing, fold 3: 0.84391
#
# No pre-processing, fold 4: 0.65027
# Standard pre-processing, fold 4: 0.88329
# Min-max pre-processing, fold 4: 0.83592
#
# ======================================================
# No pre-processing average: 0.63365
# Standard pre-processing average: 0.88219
# Min-max pre-processing average: 0.83975
# ======================================================
#
# Hidden layers: 200. Alpha value: 0.001
# No pre-processing, fold 1: 0.58688
# Standard pre-processing, fold 1: 0.87480
# Min-max pre-processing, fold 1: 0.82933
# c:\users\jerem_000\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# No pre-processing, fold 2: 0.63675
# Standard pre-processing, fold 2: 0.89117
# Min-max pre-processing, fold 2: 0.84613
#
# No pre-processing, fold 3: 0.59034
# Standard pre-processing, fold 3: 0.88120
# Min-max pre-processing, fold 3: 0.84341
#
# No pre-processing, fold 4: 0.62935
# Standard pre-processing, fold 4: 0.88347
# Min-max pre-processing, fold 4: 0.83547
#
# ======================================================
# No pre-processing average: 0.61083
# Standard pre-processing average: 0.88266
# Min-max pre-processing average: 0.83859
# ======================================================
#
# Hidden layers: 200. Alpha value: 0.01
# No pre-processing, fold 1: 0.54068
# Standard pre-processing, fold 1: 0.87819
# Min-max pre-processing, fold 1: 0.83012
#
# No pre-processing, fold 2: 0.57234
# Standard pre-processing, fold 2: 0.88858
# Min-max pre-processing, fold 2: 0.84240
#
# No pre-processing, fold 3: 0.64803
# Standard pre-processing, fold 3: 0.87817
# Min-max pre-processing, fold 3: 0.84586
#
# No pre-processing, fold 4: 0.60793
# Standard pre-processing, fold 4: 0.88430
# Min-max pre-processing, fold 4: 0.83565
#
# ======================================================
# No pre-processing average: 0.59225
# Standard pre-processing average: 0.88231
# Min-max pre-processing average: 0.83851
# ======================================================
#
# Hidden layers: 200. Alpha value: 0.1
# No pre-processing, fold 1: 0.66303
# Standard pre-processing, fold 1: 0.87594
# Min-max pre-processing, fold 1: 0.81606
#
# No pre-processing, fold 2: 0.59487
# Standard pre-processing, fold 2: 0.88881
# Min-max pre-processing, fold 2: 0.83672
#
# No pre-processing, fold 3: 0.57575
# Standard pre-processing, fold 3: 0.87668
# Min-max pre-processing, fold 3: 0.83314
#
# No pre-processing, fold 4: 0.65287
# Standard pre-processing, fold 4: 0.86935
# Min-max pre-processing, fold 4: 0.82537
#
# ======================================================
# No pre-processing average: 0.62163
# Standard pre-processing average: 0.87770
# Min-max pre-processing average: 0.82782
# ======================================================
#
# Hidden layers: 200. Alpha value: 1
# No pre-processing, fold 1: 0.47360
# Standard pre-processing, fold 1: 0.84211
# Min-max pre-processing, fold 1: 0.77505
#
# No pre-processing, fold 2: 0.55899
# Standard pre-processing, fold 2: 0.86653
# Min-max pre-processing, fold 2: 0.78629
#
# No pre-processing, fold 3: 0.59692
# Standard pre-processing, fold 3: 0.85234
# Min-max pre-processing, fold 3: 0.77160
#
# No pre-processing, fold 4: 0.66134
# Standard pre-processing, fold 4: 0.84017
# Min-max pre-processing, fold 4: 0.78268
#
# ======================================================
# No pre-processing average: 0.57271
# Standard pre-processing average: 0.85029
# Min-max pre-processing average: 0.77891
# ======================================================
#
# Hidden layers: 200. Alpha value: 10
# No pre-processing, fold 1: 0.60789
# Standard pre-processing, fold 1: 0.73345
# Min-max pre-processing, fold 1: 0.50567
#
# No pre-processing, fold 2: 0.60637
# Standard pre-processing, fold 2: 0.75784
# Min-max pre-processing, fold 2: 0.56409
#
# No pre-processing, fold 3: 0.64579
# Standard pre-processing, fold 3: 0.73193
# Min-max pre-processing, fold 3: 0.52583
#
# No pre-processing, fold 4: 0.58958
# Standard pre-processing, fold 4: 0.75110
# Min-max pre-processing, fold 4: 0.52743
#
# ======================================================
# No pre-processing average: 0.61241
# Standard pre-processing average: 0.74358
# Min-max pre-processing average: 0.53075
# ======================================================
#
# Hidden layers: (30, 30). Alpha value: 0.0001
# No pre-processing, fold 1: 0.63988
# Standard pre-processing, fold 1: 0.86398
# Min-max pre-processing, fold 1: 0.81599
#
# No pre-processing, fold 2: 0.65687
# Standard pre-processing, fold 2: 0.87510
# Min-max pre-processing, fold 2: 0.84098
#
# No pre-processing, fold 3: 0.70787
# Standard pre-processing, fold 3: 0.86546
# Min-max pre-processing, fold 3: 0.82316
#
# No pre-processing, fold 4: 0.61787
# Standard pre-processing, fold 4: 0.86642
# Min-max pre-processing, fold 4: 0.81710
#
# ======================================================
# No pre-processing average: 0.65562
# Standard pre-processing average: 0.86774
# Min-max pre-processing average: 0.82431
# ======================================================
#
# Hidden layers: (30, 30). Alpha value: 0.001
# No pre-processing, fold 1: 0.62313
# Standard pre-processing, fold 1: 0.86148
# Min-max pre-processing, fold 1: 0.81574
#
# No pre-processing, fold 2: 0.62025
# Standard pre-processing, fold 2: 0.87458
# Min-max pre-processing, fold 2: 0.82831
#
# No pre-processing, fold 3: 0.70406
# Standard pre-processing, fold 3: 0.86897
# Min-max pre-processing, fold 3: 0.82239
#
# No pre-processing, fold 4: 0.71615
# Standard pre-processing, fold 4: 0.86227
# Min-max pre-processing, fold 4: 0.81615
#
# ======================================================
# No pre-processing average: 0.66590
# Standard pre-processing average: 0.86683
# Min-max pre-processing average: 0.82065
# ======================================================
#
# Hidden layers: (30, 30). Alpha value: 0.01
# No pre-processing, fold 1: 0.64335
# Standard pre-processing, fold 1: 0.85905
# Min-max pre-processing, fold 1: 0.81376
#
# No pre-processing, fold 2: 0.58729
# Standard pre-processing, fold 2: 0.87409
# Min-max pre-processing, fold 2: 0.82874
#
# No pre-processing, fold 3: 0.63330
# Standard pre-processing, fold 3: 0.86587
# Min-max pre-processing, fold 3: 0.82349
#
# No pre-processing, fold 4: 0.65731
# Standard pre-processing, fold 4: 0.86762
# Min-max pre-processing, fold 4: 0.81984
#
# ======================================================
# No pre-processing average: 0.63031
# Standard pre-processing average: 0.86666
# Min-max pre-processing average: 0.82146
# ======================================================
#
# Hidden layers: (30, 30). Alpha value: 0.1
# No pre-processing, fold 1: 0.67952
# Standard pre-processing, fold 1: 0.86362
# Min-max pre-processing, fold 1: 0.81965
#
# No pre-processing, fold 2: 0.66860
# Standard pre-processing, fold 2: 0.87394
# Min-max pre-processing, fold 2: 0.82397
#
# No pre-processing, fold 3: 0.70435
# Standard pre-processing, fold 3: 0.86892
# Min-max pre-processing, fold 3: 0.82085
#
# No pre-processing, fold 4: 0.67758
# Standard pre-processing, fold 4: 0.86828
# Min-max pre-processing, fold 4: 0.81746
#
# ======================================================
# No pre-processing average: 0.68251
# Standard pre-processing average: 0.86869
# Min-max pre-processing average: 0.82048
# ======================================================
#
# Hidden layers: (30, 30). Alpha value: 1
# No pre-processing, fold 1: 0.66920
# Standard pre-processing, fold 1: 0.84847
# Min-max pre-processing, fold 1: 0.76266
#
# No pre-processing, fold 2: 0.62295
# Standard pre-processing, fold 2: 0.85145
# Min-max pre-processing, fold 2: 0.77434
#
# No pre-processing, fold 3: 0.67121
# Standard pre-processing, fold 3: 0.85452
# Min-max pre-processing, fold 3: 0.77501
#
# No pre-processing, fold 4: 0.63778
# Standard pre-processing, fold 4: 0.85849
# Min-max pre-processing, fold 4: 0.77904
#
# ======================================================
# No pre-processing average: 0.65029
# Standard pre-processing average: 0.85323
# Min-max pre-processing average: 0.77276
# ======================================================
#
# Hidden layers: (30, 30). Alpha value: 10
# No pre-processing, fold 1: 0.67564
# Standard pre-processing, fold 1: 0.73177
# Min-max pre-processing, fold 1: 0.52166
#
# No pre-processing, fold 2: 0.67432
# Standard pre-processing, fold 2: 0.75597
# Min-max pre-processing, fold 2: 0.55865
#
# No pre-processing, fold 3: 0.71145
# Standard pre-processing, fold 3: 0.73411
# Min-max pre-processing, fold 3: 0.55699
#
# No pre-processing, fold 4: 0.63698
# Standard pre-processing, fold 4: 0.74305
# Min-max pre-processing, fold 4: 0.53650
#
# ======================================================
# No pre-processing average: 0.67460
# Standard pre-processing average: 0.74122
# Min-max pre-processing average: 0.54345
# ======================================================
#
# Hidden layers: (200, 200). Alpha value: 0.0001
# No pre-processing, fold 1: 0.55454
# Standard pre-processing, fold 1: 0.88213
# Min-max pre-processing, fold 1: 0.82145
#
# No pre-processing, fold 2: 0.38191
# Standard pre-processing, fold 2: 0.89610
# Min-max pre-processing, fold 2: 0.83813
# No pre-processing, fold 3: 0.60767
# Standard pre-processing, fold 3: 0.88461
# Min-max pre-processing, fold 3: 0.84486
#
# No pre-processing, fold 4: 0.60322
# Standard pre-processing, fold 4: 0.87805
# Min-max pre-processing, fold 4: 0.83156
#
# ======================================================
# No pre-processing average: 0.53683
# Standard pre-processing average: 0.88522
# Min-max pre-processing average: 0.83400
# ======================================================
#
# Hidden layers: (200, 200). Alpha value: 0.001
# No pre-processing, fold 1: 0.22600
# Standard pre-processing, fold 1: 0.87985
# Min-max pre-processing, fold 1: 0.82299
#
# No pre-processing, fold 2: 0.50765
# Standard pre-processing, fold 2: 0.89986
# Min-max pre-processing, fold 2: 0.83683
#
# No pre-processing, fold 3: 0.55286
# Standard pre-processing, fold 3: 0.88233
# Min-max pre-processing, fold 3: 0.85591
#
# No pre-processing, fold 4: 0.27240
# Standard pre-processing, fold 4: 0.88092
# Min-max pre-processing, fold 4: 0.83253
#
# ======================================================
# No pre-processing average: 0.38973
# Standard pre-processing average: 0.88574
# Min-max pre-processing average: 0.83706
# ======================================================
#
# Hidden layers: (200, 200). Alpha value: 0.01
# No pre-processing, fold 1: 0.59395
# Standard pre-processing, fold 1: 0.88380
# Min-max pre-processing, fold 1: 0.82297
#
# No pre-processing, fold 2: 0.39342
# Standard pre-processing, fold 2: 0.89782
# Min-max pre-processing, fold 2: 0.83543
#
# No pre-processing, fold 3: 0.68156
# Standard pre-processing, fold 3: 0.88058
# Min-max pre-processing, fold 3: 0.84456
#
# No pre-processing, fold 4: 0.66256
# Standard pre-processing, fold 4: 0.87807
# Min-max pre-processing, fold 4: 0.83493
#
# ======================================================
# No pre-processing average: 0.58287
# Standard pre-processing average: 0.88507
# Min-max pre-processing average: 0.83447
# ======================================================
#
# Hidden layers: (200, 200). Alpha value: 0.1
# No pre-processing, fold 1: 0.55770
# Standard pre-processing, fold 1: 0.87957
# Min-max pre-processing, fold 1: 0.81917
#
# No pre-processing, fold 2: 0.45018
# Standard pre-processing, fold 2: 0.88912
# Min-max pre-processing, fold 2: 0.83983
#
# No pre-processing, fold 3: 0.63818
# Standard pre-processing, fold 3: 0.88604
# Min-max pre-processing, fold 3: 0.83550
#
# No pre-processing, fold 4: 0.56298
# Standard pre-processing, fold 4: 0.87867
# Min-max pre-processing, fold 4: 0.82600
#
# ======================================================
# No pre-processing average: 0.55226
# Standard pre-processing average: 0.88335
# Min-max pre-processing average: 0.83012
# ======================================================
#
# Hidden layers: (200, 200). Alpha value: 1
# No pre-processing, fold 1: 0.50691
# Standard pre-processing, fold 1: 0.86816
# Min-max pre-processing, fold 1: 0.77576
#
# No pre-processing, fold 2: 0.59865
# Standard pre-processing, fold 2: 0.87468
# Min-max pre-processing, fold 2: 0.79520
#
# No pre-processing, fold 3: 0.55604
# Standard pre-processing, fold 3: 0.86573
# Min-max pre-processing, fold 3: 0.79168
#
# No pre-processing, fold 4: 0.53590
# Standard pre-processing, fold 4: 0.85685
# Min-max pre-processing, fold 4: 0.77976
#
# ======================================================
# No pre-processing average: 0.54938
# Standard pre-processing average: 0.86636
# Min-max pre-processing average: 0.78560
# ======================================================
#
# Hidden layers: (200, 200). Alpha value: 10
# No pre-processing, fold 1: 0.35821
# Standard pre-processing, fold 1: 0.72281
# Min-max pre-processing, fold 1: 0.53580
#
# No pre-processing, fold 2: 0.69482
# Standard pre-processing, fold 2: 0.75289
# Min-max pre-processing, fold 2: 0.57815
#
# No pre-processing, fold 3: 0.62485
# Standard pre-processing, fold 3: 0.72475
# Min-max pre-processing, fold 3: 0.56462
#
# No pre-processing, fold 4: 0.55020
# Standard pre-processing, fold 4: 0.73930
# Min-max pre-processing, fold 4: 0.55574
#
# ======================================================
# No pre-processing average: 0.55702
# Standard pre-processing average: 0.73494
# Min-max pre-processing average: 0.55858
# ======================================================
